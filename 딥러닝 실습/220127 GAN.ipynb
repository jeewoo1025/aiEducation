# %% [markdown]
# ## Implement with MNIST
#
# 0 : fake <br>
# 1 : real <br>

# %%
import tensorflow as tf
import numpy as np
import matplotlib 

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import os

# %%
num_epoch = 100000
batch_size = 64
num_input = 28*28
num_latent_variable = 100
num_hidden = 128
learning_rate = 0.001

X = tf.placeholder(tf.float32, [None, num_input])
z = tf.placeholder(tf.float32, [None, num_latent_variable])

# Generator 변수들 설정
# 100 -> 128 -> 784
with tf.variable_scope('generator'):
    # 히든 레이어 파라미터
    G_W1 = tf.Variable(tf.random_normal(shape=[num_latent_variable, num_hidden], stddev=5e-2))
    G_b1 = tf.Variable(tf.constant(0.1, shape=[num_hidden]))

    # 아웃풋 레이터 파라미터
    G_W2 = tf.Variable(tf.random_normal(shape=[num_hidden, num_input], stddev=5e-2))
    G_b2 = tf.Variable(tf.constant(0.1, shape=[num_input]))

# Discriminator 변수들 설정
# 784 -> 128 -> 1
with tf.variable_scope('discriminator'):
    # 히든 레이어 파라미터
    D_W1 = tf.Variable(tf.random_normal(shape=[num_input, num_hidden], stddev=5e-2))
    D_b1 = tf.Variable(tf.constant(0.1, shape=[num_hidden]))

    # 아웃풋 레이어 파라미터
    D_W2 = tf.Variable(tf.random_normal(shape=[num_hidden, 1], stddev=5e-2))
    D_b2 = tf.Variable(tf.constant(0.1, shape=[1]))
# Out:
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Input : z from latent Variable, output : 생성된 MNIST 이미지
def build_generator(X):
    hidden_layer = tf.nn.relu((tf.matmul(X, G_W1) + G_b1))
    output_layer = tf.matmul(hidden_layer, G_W2) + G_b2
    generated_mnist_image = tf.nn.sigmoid(output_layer)
    return generated_mnist_image


# input : 인풋 이미지, output : 예측값(0 or 1), logits : sigmoid를 씌우기 전 출력값
def build_discriminator(X):
    hidden_layer = tf.nn.relu((tf.matmul(X, D_W1) + D_b1))
    logits = tf.matmul(hidden_layer, D_W2) + D_b2
    predicted_value = tf.nn.sigmoid(logits)
    return predicted_value, logits

# %% [markdown]
# Discriminator의 손실함수
# - 실제 이미지일 확률이 높으면 1에 가까운 값을 반환하고
# - 가짜 이미지일 확률이 높으면 0에 가까운 값을 반환하도록 구현

# %%
# 생성자를 선언
G = build_generator(z)

# 구별자를 선언
D_real, D_real_logits = build_discriminator(X)  # D(x)
D_fake, D_fake_logits = build_discriminator(G)  # D(G(z))

# %%
# Discriminator의 cost function 선언
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones_like(D_real_logits)))  # log(D(x))
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros_like(D_fake_logits))) # log(1-D(G(z)))
d_loss = d_loss_real + d_loss_fake  # log(D(x)) + log(1-D(G(z)))

# %%
# Generator의 cost function 선언
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones_like(D_fake_logits)))  # log(D(G(z)))

# %% [markdown]
# ## Training Process
#
# * mini-batch학습마다 구성
# * 우선 매 step마다 mini batch로 G,D 샘플링
#     * Dataset으로부터 얻은 x의 mini-batch
#     * Uniform distribution으로부터 얻은 latent z의 mini-batch
# * 2개의 Gradient step이 동시에 일어남
#     * J_D를 감소시키는 방향으로 D-param만을 업데이트하는 gradient descent
#     * J_G를 감소시키는 방향으로 G_param만을 업데이트하는 gradient descent

# %%
# 전체 파라미터를 Discriminator와 관련된 파라미터와 Generator로 관련된 파라미터로 나눔
tvar = tf.trainable_variables()
dvar = [var for var in tvar if 'discriminator' in var.name]
gvar = [var for var in tvar if 'generator' in var.name]

# Discriminator와 Generator의 Optimizer를 정의함
d_train_step = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=dvar)
g_train_step = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=gvar)

# %%
# 데이터 다운로드
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)
# Out:
# WARNING:tensorflow:From C:\Users\SULJEE~1\AppData\Local\Temp/ipykernel_10088/1829467149.py:4: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\suljeewoo\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_img = 0
if not os.path.exists('generated_output/'):
    os.makedirs('generated_output/')

# %%
print("9".zfill(3))
# Out:
# 009

# %%
def plot(samples):
    fig = plt.figure(figsize=(8,8))
    gs = gridspec.GridSpec(8,8)
    gs.update(wspace=0.05, hspace=0.05)

    for i,sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        plt.imshow(sample.reshape(28,28))
    return fig

# %%
# 학습 시작
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # num_epoch 횟수만큼 최적화를 수행함
    for i in range(num_epoch):
        batch_X, _ = mnist.train.next_batch(batch_size)
        
        # latent Variable의 인풋으로 사용한 noise를 Uniform Distribution에서 batch_size개 만큼 샘플링함
        batch_noise = np.random.uniform(-1., 1., [batch_size, 100])

        # 500번 반복할 때마다 학습된 G를 통해 생성된 이미지를 저장함
        if i%500 == 0:
            samples = sess.run(G, feed_dict={z:np.random.uniform(-1., 1., [64, 100])})
            fig = plot(samples)
            plt.savefig('generated_output/%s.png'%str(num_img).zfill(3), bbox_inches='tight')
            num_img += 1
            plt.close(fig)

        # Discriminator 최적화를 수행하고 Discriminator의 손실함수를 return
        _, d_loss_print = sess.run([d_train_step, d_loss], feed_dict={X:batch_X, z:batch_noise})

        # Generator 최적화를 수행하고 Generator 손실함수를 return
        _, g_loss_print = sess.run([g_train_step, g_loss], feed_dict={z: batch_noise})

        # 100번 반복할 때마다 Discriminator의 손실함수와 Generator의 손실함수를 출력한다
        if i%100 == 0:
            print('반복(Epoch) : %d, Generator 손실함수(g_loss): %f, Discriminator 손실함수 (d_loss): %f'%(i, g_loss_print, d_loss_print))
# Out:
# 반복(Epoch) : 0, Generator 손실함수(g_loss): 1.205080, Discriminator 손실함수 (d_loss): 1.356527
# 반복(Epoch) : 100, Generator 손실함수(g_loss): 3.328565, Discriminator 손실함수 (d_loss): 0.263443
# 반복(Epoch) : 200, Generator 손실함수(g_loss): 4.272277, Discriminator 손실함수 (d_loss): 0.112441
# 반복(Epoch) : 300, Generator 손실함수(g_loss): 4.915137, Discriminator 손실함수 (d_loss): 0.027982
# 반복(Epoch) : 400, Generator 손실함수(g_loss): 4.731428, Discriminator 손실함수 (d_loss): 0.034692
# 반복(Epoch) : 500, Generator 손실함수(g_loss): 5.428992, Discriminator 손실함수 (d_loss): 0.020949
# 반복(Epoch) : 600, Generator 손실함수(g_loss): 9.594582, Discriminator 손실함수 (d_loss): 0.010140
# 반복(Epoch) : 700, Generator 손실함수(g_loss): 9.954645, Discriminator 손실함수 (d_loss): 0.009327
# 반복(Epoch) : 800, Generator 손실함수(g_loss): 7.771447, Discriminator 손실함수 (d_loss): 0.015167
# 반복(Epoch) : 900, Generator 손실함수(g_loss): 15.141100, Discriminator 손실함수 (d_loss): 0.014185
# 반복(Epoch) : 1000, Generator 손실함수(g_loss): 11.284182, Discriminator 손실함수 (d_loss): 0.029712
# 반복(Epoch) : 1100, Generator 손실함수(g_loss): 5.969739, Discriminator 손실함수 (d_loss): 0.091312
# 반복(Epoch) : 1200, Generator 손실함수(g_loss): 6.052544, Discriminator 손실함수 (d_loss): 0.043262
# 반복(Epoch) : 1300, Generator 손실함수(g_loss): 7.416872, Discriminator 손실함수 (d_loss): 0.006798
# 반복(Epoch) : 1400, Generator 손실함수(g_loss): 7.696466, Discriminator 손실함수 (d_loss): 0.012524
# 반복(Epoch) : 1500, Generator 손실함수(g_loss): 6.987612, Discriminator 손실함수 (d_loss): 0.018777
# 반복(Epoch) : 1600, Generator 손실함수(g_loss): 7.144086, Discriminator 손실함수 (d_loss): 0.045939
# 반복(Epoch) : 1700, Generator 손실함수(g_loss): 7.016966, Discriminator 손실함수 (d_loss): 0.025842
# 반복(Epoch) : 1800, Generator 손실함수(g_loss): 9.028208, Discriminator 손실함수 (d_loss): 0.010903
# 반복(Epoch) : 1900, Generator 손실함수(g_loss): 6.720551, Discriminator 손실함수 (d_loss): 0.008264
# 반복(Epoch) : 2000, Generator 손실함수(g_loss): 7.968287, Discriminator 손실함수 (d_loss): 0.090777
# 반복(Epoch) : 2100, Generator 손실함수(g_loss): 6.706337, Discriminator 손실함수 (d_loss): 0.011856
# 반복(Epoch) : 2200, Generator 손실함수(g_loss): 6.206575, Discriminator 손실함수 (d_loss): 0.059339
# 반복(Epoch) : 2300, Generator 손실함수(g_loss): 6.732523, Discriminator 손실함수 (d_loss): 0.016392
# 반복(Epoch) : 2400, Generator 손실함수(g_loss): 5.574396, Discriminator 손실함수 (d_loss): 0.068826
# 반복(Epoch) : 2500, Generator 손실함수(g_loss): 5.805065, Discriminator 손실함수 (d_loss): 0.017446
# 반복(Epoch) : 2600, Generator 손실함수(g_loss): 6.131517, Discriminator 손실함수 (d_loss): 0.013513
# 반복(Epoch) : 2700, Generator 손실함수(g_loss): 5.671720, Discriminator 손실함수 (d_loss): 0.047260
# 반복(Epoch) : 2800, Generator 손실함수(g_loss): 6.603981, Discriminator 손실함수 (d_loss): 0.041233
# 반복(Epoch) : 2900, Generator 손실함수(g_loss): 7.398351, Discriminator 손실함수 (d_loss): 0.055426
# 반복(Epoch) : 3000, Generator 손실함수(g_loss): 5.695887, Discriminator 손실함수 (d_loss): 0.043018
# 반복(Epoch) : 3100, Generator 손실함수(g_loss): 4.925061, Discriminator 손실함수 (d_loss): 0.047614
# 반복(Epoch) : 3200, Generator 손실함수(g_loss): 4.257647, Discriminator 손실함수 (d_loss): 0.079233
# 반복(Epoch) : 3300, Generator 손실함수(g_loss): 5.031153, Discriminator 손실함수 (d_loss): 0.085945
# 반복(Epoch) : 3400, Generator 손실함수(g_loss): 6.494370, Discriminator 손실함수 (d_loss): 0.063363
# 반복(Epoch) : 3500, Generator 손실함수(g_loss): 6.393061, Discriminator 손실함수 (d_loss): 0.049404
# 반복(Epoch) : 3600, Generator 손실함수(g_loss): 6.311265, Discriminator 손실함수 (d_loss): 0.070198
# 반복(Epoch) : 3700, Generator 손실함수(g_loss): 4.613314, Discriminator 손실함수 (d_loss): 0.071289
# 반복(Epoch) : 3800, Generator 손실함수(g_loss): 5.204231, Discriminator 손실함수 (d_loss): 0.185461
# 반복(Epoch) : 3900, Generator 손실함수(g_loss): 4.452182, Discriminator 손실함수 (d_loss): 0.129233
# 반복(Epoch) : 4000, Generator 손실함수(g_loss): 4.761329, Discriminator 손실함수 (d_loss): 0.111286
# 반복(Epoch) : 4100, Generator 손실함수(g_loss): 4.562976, Discriminator 손실함수 (d_loss): 0.128263
# 반복(Epoch) : 4200, Generator 손실함수(g_loss): 4.361237, Discriminator 손실함수 (d_loss): 0.148884
# 반복(Epoch) : 4300, Generator 손실함수(g_loss): 6.226155, Discriminator 손실함수 (d_loss): 0.096501
# 반복(Epoch) : 4400, Generator 손실함수(g_loss): 5.447011, Discriminator 손실함수 (d_loss): 0.229591
# 반복(Epoch) : 4500, Generator 손실함수(g_loss): 6.147665, Discriminator 손실함수 (d_loss): 0.107710
# 반복(Epoch) : 4600, Generator 손실함수(g_loss): 5.260126, Discriminator 손실함수 (d_loss): 0.115651
# 반복(Epoch) : 4700, Generator 손실함수(g_loss): 5.804510, Discriminator 손실함수 (d_loss): 0.126602
# 반복(Epoch) : 4800, Generator 손실함수(g_loss): 5.451486, Discriminator 손실함수 (d_loss): 0.300373
# 반복(Epoch) : 4900, Generator 손실함수(g_loss): 5.056463, Discriminator 손실함수 (d_loss): 0.236854
# 반복(Epoch) : 5000, Generator 손실함수(g_loss): 5.225251, Discriminator 손실함수 (d_loss): 0.111716
# 반복(Epoch) : 5100, Generator 손실함수(g_loss): 4.242919, Discriminator 손실함수 (d_loss): 0.286735
# 반복(Epoch) : 5200, Generator 손실함수(g_loss): 4.359613, Discriminator 손실함수 (d_loss): 0.297534
# 반복(Epoch) : 5300, Generator 손실함수(g_loss): 4.070588, Discriminator 손실함수 (d_loss): 0.280161
# 반복(Epoch) : 5400, Generator 손실함수(g_loss): 4.476859, Discriminator 손실함수 (d_loss): 0.236007
# 반복(Epoch) : 5500, Generator 손실함수(g_loss): 4.805948, Discriminator 손실함수 (d_loss): 0.283481
# 반복(Epoch) : 5600, Generator 손실함수(g_loss): 4.612981, Discriminator 손실함수 (d_loss): 0.180748
# 반복(Epoch) : 5700, Generator 손실함수(g_loss): 5.433191, Discriminator 손실함수 (d_loss): 0.195414
# 반복(Epoch) : 5800, Generator 손실함수(g_loss): 5.643049, Discriminator 손실함수 (d_loss): 0.098551
# 반복(Epoch) : 5900, Generator 손실함수(g_loss): 4.521655, Discriminator 손실함수 (d_loss): 0.260634
# 반복(Epoch) : 6000, Generator 손실함수(g_loss): 4.471757, Discriminator 손실함수 (d_loss): 0.279814
# 반복(Epoch) : 6100, Generator 손실함수(g_loss): 4.545872, Discriminator 손실함수 (d_loss): 0.152715
# 반복(Epoch) : 6200, Generator 손실함수(g_loss): 3.942514, Discriminator 손실함수 (d_loss): 0.340489
# 반복(Epoch) : 6300, Generator 손실함수(g_loss): 4.714253, Discriminator 손실함수 (d_loss): 0.354668
# 반복(Epoch) : 6400, Generator 손실함수(g_loss): 5.136801, Discriminator 손실함수 (d_loss): 0.252974
# 반복(Epoch) : 6500, Generator 손실함수(g_loss): 3.822478, Discriminator 손실함수 (d_loss): 0.629366
# 반복(Epoch) : 6600, Generator 손실함수(g_loss): 3.994118, Discriminator 손실함수 (d_loss): 0.472733
# 반복(Epoch) : 6700, Generator 손실함수(g_loss): 3.845136, Discriminator 손실함수 (d_loss): 0.253885
# 반복(Epoch) : 6800, Generator 손실함수(g_loss): 3.721407, Discriminator 손실함수 (d_loss): 0.344952
# 반복(Epoch) : 6900, Generator 손실함수(g_loss): 3.933423, Discriminator 손실함수 (d_loss): 0.383121
# 반복(Epoch) : 7000, Generator 손실함수(g_loss): 3.998988, Discriminator 손실함수 (d_loss): 0.158465
# 반복(Epoch) : 7100, Generator 손실함수(g_loss): 3.744837, Discriminator 손실함수 (d_loss): 0.225114
# 반복(Epoch) : 7200, Generator 손실함수(g_loss): 3.178271, Discriminator 손실함수 (d_loss): 0.442468
# 반복(Epoch) : 7300, Generator 손실함수(g_loss): 3.080983, Discriminator 손실함수 (d_loss): 0.533015
# 반복(Epoch) : 7400, Generator 손실함수(g_loss): 3.695086, Discriminator 손실함수 (d_loss): 0.503761
# 반복(Epoch) : 7500, Generator 손실함수(g_loss): 4.017123, Discriminator 손실함수 (d_loss): 0.419303
# 반복(Epoch) : 7600, Generator 손실함수(g_loss): 3.768446, Discriminator 손실함수 (d_loss): 0.701768
# 반복(Epoch) : 7700, Generator 손실함수(g_loss): 3.578250, Discriminator 손실함수 (d_loss): 0.671101
# 반복(Epoch) : 7800, Generator 손실함수(g_loss): 4.378554, Discriminator 손실함수 (d_loss): 0.266246
# 반복(Epoch) : 7900, Generator 손실함수(g_loss): 3.858572, Discriminator 손실함수 (d_loss): 0.363930
# 반복(Epoch) : 8000, Generator 손실함수(g_loss): 2.272921, Discriminator 손실함수 (d_loss): 0.639973
# 반복(Epoch) : 8100, Generator 손실함수(g_loss): 4.048681, Discriminator 손실함수 (d_loss): 0.581829
# 반복(Epoch) : 8200, Generator 손실함수(g_loss): 2.343132, Discriminator 손실함수 (d_loss): 0.585491
# 반복(Epoch) : 8300, Generator 손실함수(g_loss): 3.564714, Discriminator 손실함수 (d_loss): 0.465866
# 반복(Epoch) : 8400, Generator 손실함수(g_loss): 3.072580, Discriminator 손실함수 (d_loss): 0.391376
# 반복(Epoch) : 8500, Generator 손실함수(g_loss): 2.930882, Discriminator 손실함수 (d_loss): 0.348429
# 반복(Epoch) : 8600, Generator 손실함수(g_loss): 2.848673, Discriminator 손실함수 (d_loss): 0.568870
# 반복(Epoch) : 8700, Generator 손실함수(g_loss): 2.621725, Discriminator 손실함수 (d_loss): 0.430829
# 반복(Epoch) : 8800, Generator 손실함수(g_loss): 3.019532, Discriminator 손실함수 (d_loss): 0.446015
# 반복(Epoch) : 8900, Generator 손실함수(g_loss): 2.664420, Discriminator 손실함수 (d_loss): 0.451582
# 반복(Epoch) : 9000, Generator 손실함수(g_loss): 2.989913, Discriminator 손실함수 (d_loss): 0.587539
# 반복(Epoch) : 9100, Generator 손실함수(g_loss): 2.736878, Discriminator 손실함수 (d_loss): 0.649041
# 반복(Epoch) : 9200, Generator 손실함수(g_loss): 2.780255, Discriminator 손실함수 (d_loss): 0.525894
# 반복(Epoch) : 9300, Generator 손실함수(g_loss): 2.915704, Discriminator 손실함수 (d_loss): 0.453032
# 반복(Epoch) : 9400, Generator 손실함수(g_loss): 3.130144, Discriminator 손실함수 (d_loss): 0.553212
# 반복(Epoch) : 9500, Generator 손실함수(g_loss): 2.484673, Discriminator 손실함수 (d_loss): 0.688147
# 반복(Epoch) : 9600, Generator 손실함수(g_loss): 2.407786, Discriminator 손실함수 (d_loss): 0.564610
# 반복(Epoch) : 9700, Generator 손실함수(g_loss): 3.100849, Discriminator 손실함수 (d_loss): 0.359689
# 반복(Epoch) : 9800, Generator 손실함수(g_loss): 2.263282, Discriminator 손실함수 (d_loss): 0.411085
# 반복(Epoch) : 9900, Generator 손실함수(g_loss): 2.901881, Discriminator 손실함수 (d_loss): 0.398488
# 반복(Epoch) : 10000, Generator 손실함수(g_loss): 3.304013, Discriminator 손실함수 (d_loss): 0.543505
# 반복(Epoch) : 10100, Generator 손실함수(g_loss): 2.918826, Discriminator 손실함수 (d_loss): 0.483735
# 반복(Epoch) : 10200, Generator 손실함수(g_loss): 3.049712, Discriminator 손실함수 (d_loss): 0.645068
# 반복(Epoch) : 10300, Generator 손실함수(g_loss): 3.284446, Discriminator 손실함수 (d_loss): 0.406576
# 반복(Epoch) : 10400, Generator 손실함수(g_loss): 2.553024, Discriminator 손실함수 (d_loss): 0.544243
# 반복(Epoch) : 10500, Generator 손실함수(g_loss): 2.610201, Discriminator 손실함수 (d_loss): 0.602354
# 반복(Epoch) : 10600, Generator 손실함수(g_loss): 2.717125, Discriminator 손실함수 (d_loss): 0.715976
# 반복(Epoch) : 10700, Generator 손실함수(g_loss): 3.229719, Discriminator 손실함수 (d_loss): 0.499970
# 반복(Epoch) : 10800, Generator 손실함수(g_loss): 3.010410, Discriminator 손실함수 (d_loss): 0.446324
# 반복(Epoch) : 10900, Generator 손실함수(g_loss): 2.797325, Discriminator 손실함수 (d_loss): 0.642258
# 반복(Epoch) : 11000, Generator 손실함수(g_loss): 2.809544, Discriminator 손실함수 (d_loss): 0.531050
# 반복(Epoch) : 11100, Generator 손실함수(g_loss): 2.640556, Discriminator 손실함수 (d_loss): 0.512155
# 반복(Epoch) : 11200, Generator 손실함수(g_loss): 3.340488, Discriminator 손실함수 (d_loss): 0.516257
# 반복(Epoch) : 11300, Generator 손실함수(g_loss): 2.690444, Discriminator 손실함수 (d_loss): 0.752790
# 반복(Epoch) : 11400, Generator 손실함수(g_loss): 2.533824, Discriminator 손실함수 (d_loss): 0.671893
# 반복(Epoch) : 11500, Generator 손실함수(g_loss): 2.332853, Discriminator 손실함수 (d_loss): 0.544082
# 반복(Epoch) : 11600, Generator 손실함수(g_loss): 2.037734, Discriminator 손실함수 (d_loss): 0.781672
# 반복(Epoch) : 11700, Generator 손실함수(g_loss): 2.536157, Discriminator 손실함수 (d_loss): 0.622982
# 반복(Epoch) : 11800, Generator 손실함수(g_loss): 2.393709, Discriminator 손실함수 (d_loss): 0.653465
# 반복(Epoch) : 11900, Generator 손실함수(g_loss): 2.409829, Discriminator 손실함수 (d_loss): 0.727836
# 반복(Epoch) : 12000, Generator 손실함수(g_loss): 2.510107, Discriminator 손실함수 (d_loss): 0.518691
# 반복(Epoch) : 12100, Generator 손실함수(g_loss): 2.228023, Discriminator 손실함수 (d_loss): 0.582900
# 반복(Epoch) : 12200, Generator 손실함수(g_loss): 2.412712, Discriminator 손실함수 (d_loss): 0.602206
# 반복(Epoch) : 12300, Generator 손실함수(g_loss): 2.407025, Discriminator 손실함수 (d_loss): 0.601492
# 반복(Epoch) : 12400, Generator 손실함수(g_loss): 2.063972, Discriminator 손실함수 (d_loss): 0.653747
# 반복(Epoch) : 12500, Generator 손실함수(g_loss): 2.502234, Discriminator 손실함수 (d_loss): 0.587043
# 반복(Epoch) : 12600, Generator 손실함수(g_loss): 2.425304, Discriminator 손실함수 (d_loss): 0.570567
# 반복(Epoch) : 12700, Generator 손실함수(g_loss): 2.183448, Discriminator 손실함수 (d_loss): 0.641177
# 반복(Epoch) : 12800, Generator 손실함수(g_loss): 2.396286, Discriminator 손실함수 (d_loss): 0.587336
# 반복(Epoch) : 12900, Generator 손실함수(g_loss): 2.185538, Discriminator 손실함수 (d_loss): 0.722931
# 반복(Epoch) : 13000, Generator 손실함수(g_loss): 2.254074, Discriminator 손실함수 (d_loss): 0.773708
# 반복(Epoch) : 13100, Generator 손실함수(g_loss): 2.339185, Discriminator 손실함수 (d_loss): 0.530602
# 반복(Epoch) : 13200, Generator 손실함수(g_loss): 2.105215, Discriminator 손실함수 (d_loss): 0.680179
# 반복(Epoch) : 13300, Generator 손실함수(g_loss): 2.353342, Discriminator 손실함수 (d_loss): 0.534906
# 반복(Epoch) : 13400, Generator 손실함수(g_loss): 1.986805, Discriminator 손실함수 (d_loss): 0.657644
# 반복(Epoch) : 13500, Generator 손실함수(g_loss): 2.344377, Discriminator 손실함수 (d_loss): 0.530847
# 반복(Epoch) : 13600, Generator 손실함수(g_loss): 1.983064, Discriminator 손실함수 (d_loss): 0.721759
# 반복(Epoch) : 13700, Generator 손실함수(g_loss): 3.007400, Discriminator 손실함수 (d_loss): 0.582537
# 반복(Epoch) : 13800, Generator 손실함수(g_loss): 2.442648, Discriminator 손실함수 (d_loss): 0.661489
# 반복(Epoch) : 13900, Generator 손실함수(g_loss): 2.299491, Discriminator 손실함수 (d_loss): 0.638550
# 반복(Epoch) : 14000, Generator 손실함수(g_loss): 2.269244, Discriminator 손실함수 (d_loss): 0.581924
# 반복(Epoch) : 14100, Generator 손실함수(g_loss): 2.207948, Discriminator 손실함수 (d_loss): 0.725262
# 반복(Epoch) : 14200, Generator 손실함수(g_loss): 2.456142, Discriminator 손실함수 (d_loss): 0.815131
# 반복(Epoch) : 14300, Generator 손실함수(g_loss): 1.947148, Discriminator 손실함수 (d_loss): 0.831061
# 반복(Epoch) : 14400, Generator 손실함수(g_loss): 2.314485, Discriminator 손실함수 (d_loss): 0.695829
# 반복(Epoch) : 14500, Generator 손실함수(g_loss): 2.577188, Discriminator 손실함수 (d_loss): 0.543767
# 반복(Epoch) : 14600, Generator 손실함수(g_loss): 2.484933, Discriminator 손실함수 (d_loss): 0.831920
# 반복(Epoch) : 14700, Generator 손실함수(g_loss): 2.299150, Discriminator 손실함수 (d_loss): 0.724848
# 반복(Epoch) : 14800, Generator 손실함수(g_loss): 2.536342, Discriminator 손실함수 (d_loss): 0.577722
# 반복(Epoch) : 14900, Generator 손실함수(g_loss): 2.072722, Discriminator 손실함수 (d_loss): 0.856164
# 반복(Epoch) : 15000, Generator 손실함수(g_loss): 1.919458, Discriminator 손실함수 (d_loss): 0.600804
# 반복(Epoch) : 15100, Generator 손실함수(g_loss): 1.951838, Discriminator 손실함수 (d_loss): 0.802963
# 반복(Epoch) : 15200, Generator 손실함수(g_loss): 1.851919, Discriminator 손실함수 (d_loss): 0.710184
# 반복(Epoch) : 15300, Generator 손실함수(g_loss): 1.915849, Discriminator 손실함수 (d_loss): 0.859057
# 반복(Epoch) : 15400, Generator 손실함수(g_loss): 1.766247, Discriminator 손실함수 (d_loss): 0.595700
# 반복(Epoch) : 15500, Generator 손실함수(g_loss): 2.177967, Discriminator 손실함수 (d_loss): 0.542326
# 반복(Epoch) : 15600, Generator 손실함수(g_loss): 1.787479, Discriminator 손실함수 (d_loss): 0.741930
# 반복(Epoch) : 15700, Generator 손실함수(g_loss): 1.896556, Discriminator 손실함수 (d_loss): 0.969772
# 반복(Epoch) : 15800, Generator 손실함수(g_loss): 2.062066, Discriminator 손실함수 (d_loss): 0.597205
# 반복(Epoch) : 15900, Generator 손실함수(g_loss): 1.928587, Discriminator 손실함수 (d_loss): 0.610161
# 반복(Epoch) : 16000, Generator 손실함수(g_loss): 1.975982, Discriminator 손실함수 (d_loss): 0.885249
# 반복(Epoch) : 16100, Generator 손실함수(g_loss): 2.043453, Discriminator 손실함수 (d_loss): 1.050261
# 반복(Epoch) : 16200, Generator 손실함수(g_loss): 2.066364, Discriminator 손실함수 (d_loss): 0.648867
# 반복(Epoch) : 16300, Generator 손실함수(g_loss): 1.902684, Discriminator 손실함수 (d_loss): 0.836664
# 반복(Epoch) : 16400, Generator 손실함수(g_loss): 1.967103, Discriminator 손실함수 (d_loss): 0.579556
# 반복(Epoch) : 16500, Generator 손실함수(g_loss): 2.073211, Discriminator 손실함수 (d_loss): 0.858789
# 반복(Epoch) : 16600, Generator 손실함수(g_loss): 2.108481, Discriminator 손실함수 (d_loss): 0.738416
# 반복(Epoch) : 16700, Generator 손실함수(g_loss): 2.046245, Discriminator 손실함수 (d_loss): 0.749087
# 반복(Epoch) : 16800, Generator 손실함수(g_loss): 1.970893, Discriminator 손실함수 (d_loss): 0.774469
# 반복(Epoch) : 16900, Generator 손실함수(g_loss): 2.221981, Discriminator 손실함수 (d_loss): 0.720162
# 반복(Epoch) : 17000, Generator 손실함수(g_loss): 2.191516, Discriminator 손실함수 (d_loss): 0.632868
# 반복(Epoch) : 17100, Generator 손실함수(g_loss): 1.956613, Discriminator 손실함수 (d_loss): 0.918145
# 반복(Epoch) : 17200, Generator 손실함수(g_loss): 1.591427, Discriminator 손실함수 (d_loss): 0.959132
# 반복(Epoch) : 17300, Generator 손실함수(g_loss): 2.323166, Discriminator 손실함수 (d_loss): 0.696035
# 반복(Epoch) : 17400, Generator 손실함수(g_loss): 1.706720, Discriminator 손실함수 (d_loss): 0.859485
# 반복(Epoch) : 17500, Generator 손실함수(g_loss): 2.182193, Discriminator 손실함수 (d_loss): 0.554298
# 반복(Epoch) : 17600, Generator 손실함수(g_loss): 2.046915, Discriminator 손실함수 (d_loss): 0.645601
# 반복(Epoch) : 17700, Generator 손실함수(g_loss): 2.182731, Discriminator 손실함수 (d_loss): 0.719964
# 반복(Epoch) : 17800, Generator 손실함수(g_loss): 2.126819, Discriminator 손실함수 (d_loss): 0.765864
# 반복(Epoch) : 17900, Generator 손실함수(g_loss): 2.285365, Discriminator 손실함수 (d_loss): 0.635713
# 반복(Epoch) : 18000, Generator 손실함수(g_loss): 2.044673, Discriminator 손실함수 (d_loss): 0.784152
# 반복(Epoch) : 18100, Generator 손실함수(g_loss): 2.209934, Discriminator 손실함수 (d_loss): 0.809737
# 반복(Epoch) : 18200, Generator 손실함수(g_loss): 2.287917, Discriminator 손실함수 (d_loss): 0.871540
# 반복(Epoch) : 18300, Generator 손실함수(g_loss): 2.193452, Discriminator 손실함수 (d_loss): 0.775988
# 반복(Epoch) : 18400, Generator 손실함수(g_loss): 1.943154, Discriminator 손실함수 (d_loss): 0.831252
# 반복(Epoch) : 18500, Generator 손실함수(g_loss): 1.915786, Discriminator 손실함수 (d_loss): 0.673860
# 반복(Epoch) : 18600, Generator 손실함수(g_loss): 2.115361, Discriminator 손실함수 (d_loss): 0.703214
# 반복(Epoch) : 18700, Generator 손실함수(g_loss): 2.201626, Discriminator 손실함수 (d_loss): 0.788574
# 반복(Epoch) : 18800, Generator 손실함수(g_loss): 1.642582, Discriminator 손실함수 (d_loss): 0.894642
# 반복(Epoch) : 18900, Generator 손실함수(g_loss): 1.964182, Discriminator 손실함수 (d_loss): 0.707193
# 반복(Epoch) : 19000, Generator 손실함수(g_loss): 1.951930, Discriminator 손실함수 (d_loss): 0.669293
# 반복(Epoch) : 19100, Generator 손실함수(g_loss): 2.009001, Discriminator 손실함수 (d_loss): 0.543049
# 반복(Epoch) : 19200, Generator 손실함수(g_loss): 2.103382, Discriminator 손실함수 (d_loss): 0.888867
# 반복(Epoch) : 19300, Generator 손실함수(g_loss): 2.274260, Discriminator 손실함수 (d_loss): 0.693248
# 반복(Epoch) : 19400, Generator 손실함수(g_loss): 2.013238, Discriminator 손실함수 (d_loss): 0.714485
# 반복(Epoch) : 19500, Generator 손실함수(g_loss): 1.941167, Discriminator 손실함수 (d_loss): 0.811217
# 반복(Epoch) : 19600, Generator 손실함수(g_loss): 1.964525, Discriminator 손실함수 (d_loss): 0.723996
# 반복(Epoch) : 19700, Generator 손실함수(g_loss): 2.021947, Discriminator 손실함수 (d_loss): 0.808219
# 반복(Epoch) : 19800, Generator 손실함수(g_loss): 2.316276, Discriminator 손실함수 (d_loss): 0.776451
# 반복(Epoch) : 19900, Generator 손실함수(g_loss): 1.855240, Discriminator 손실함수 (d_loss): 0.868176
# 반복(Epoch) : 20000, Generator 손실함수(g_loss): 1.956252, Discriminator 손실함수 (d_loss): 0.905755
# 반복(Epoch) : 20100, Generator 손실함수(g_loss): 2.010816, Discriminator 손실함수 (d_loss): 0.638814
# 반복(Epoch) : 20200, Generator 손실함수(g_loss): 1.701485, Discriminator 손실함수 (d_loss): 0.958348
# 반복(Epoch) : 20300, Generator 손실함수(g_loss): 2.117302, Discriminator 손실함수 (d_loss): 0.748214
# 반복(Epoch) : 20400, Generator 손실함수(g_loss): 1.933228, Discriminator 손실함수 (d_loss): 0.694811
# 반복(Epoch) : 20500, Generator 손실함수(g_loss): 1.926322, Discriminator 손실함수 (d_loss): 0.688024
# 반복(Epoch) : 20600, Generator 손실함수(g_loss): 1.933392, Discriminator 손실함수 (d_loss): 0.725997
# 반복(Epoch) : 20700, Generator 손실함수(g_loss): 1.882311, Discriminator 손실함수 (d_loss): 0.803636
# 반복(Epoch) : 20800, Generator 손실함수(g_loss): 1.958695, Discriminator 손실함수 (d_loss): 0.680267
# 반복(Epoch) : 20900, Generator 손실함수(g_loss): 1.891389, Discriminator 손실함수 (d_loss): 0.631399
# 반복(Epoch) : 21000, Generator 손실함수(g_loss): 1.855810, Discriminator 손실함수 (d_loss): 0.903774
# 반복(Epoch) : 21100, Generator 손실함수(g_loss): 2.512646, Discriminator 손실함수 (d_loss): 0.685514
# 반복(Epoch) : 21200, Generator 손실함수(g_loss): 2.168552, Discriminator 손실함수 (d_loss): 0.647632
# 반복(Epoch) : 21300, Generator 손실함수(g_loss): 2.526042, Discriminator 손실함수 (d_loss): 0.502676
# 반복(Epoch) : 21400, Generator 손실함수(g_loss): 2.227395, Discriminator 손실함수 (d_loss): 0.896547
# 반복(Epoch) : 21500, Generator 손실함수(g_loss): 1.969360, Discriminator 손실함수 (d_loss): 0.779180
# 반복(Epoch) : 21600, Generator 손실함수(g_loss): 1.969887, Discriminator 손실함수 (d_loss): 0.656702
# 반복(Epoch) : 21700, Generator 손실함수(g_loss): 2.079515, Discriminator 손실함수 (d_loss): 0.756022
# 반복(Epoch) : 21800, Generator 손실함수(g_loss): 2.084382, Discriminator 손실함수 (d_loss): 0.773986
# 반복(Epoch) : 21900, Generator 손실함수(g_loss): 2.134466, Discriminator 손실함수 (d_loss): 0.649666
# 반복(Epoch) : 22000, Generator 손실함수(g_loss): 1.827037, Discriminator 손실함수 (d_loss): 0.950139
# 반복(Epoch) : 22100, Generator 손실함수(g_loss): 2.043256, Discriminator 손실함수 (d_loss): 0.650271
# 반복(Epoch) : 22200, Generator 손실함수(g_loss): 2.110102, Discriminator 손실함수 (d_loss): 0.773851
# 반복(Epoch) : 22300, Generator 손실함수(g_loss): 1.799968, Discriminator 손실함수 (d_loss): 0.892471
# 반복(Epoch) : 22400, Generator 손실함수(g_loss): 1.803449, Discriminator 손실함수 (d_loss): 0.889861
# 반복(Epoch) : 22500, Generator 손실함수(g_loss): 1.857241, Discriminator 손실함수 (d_loss): 0.559822
# 반복(Epoch) : 22600, Generator 손실함수(g_loss): 1.857182, Discriminator 손실함수 (d_loss): 0.733797
# 반복(Epoch) : 22700, Generator 손실함수(g_loss): 2.139336, Discriminator 손실함수 (d_loss): 0.713386
# 반복(Epoch) : 22800, Generator 손실함수(g_loss): 2.346789, Discriminator 손실함수 (d_loss): 0.822337
# 반복(Epoch) : 22900, Generator 손실함수(g_loss): 2.037740, Discriminator 손실함수 (d_loss): 0.856463
# 반복(Epoch) : 23000, Generator 손실함수(g_loss): 2.194203, Discriminator 손실함수 (d_loss): 0.705826
# 반복(Epoch) : 23100, Generator 손실함수(g_loss): 1.847161, Discriminator 손실함수 (d_loss): 0.775524
# 반복(Epoch) : 23200, Generator 손실함수(g_loss): 1.874573, Discriminator 손실함수 (d_loss): 0.770217
# 반복(Epoch) : 23300, Generator 손실함수(g_loss): 2.248709, Discriminator 손실함수 (d_loss): 0.618018
# 반복(Epoch) : 23400, Generator 손실함수(g_loss): 2.258980, Discriminator 손실함수 (d_loss): 0.726202
# 반복(Epoch) : 23500, Generator 손실함수(g_loss): 2.232808, Discriminator 손실함수 (d_loss): 0.862949
# 반복(Epoch) : 23600, Generator 손실함수(g_loss): 1.836419, Discriminator 손실함수 (d_loss): 0.834261
# 반복(Epoch) : 23700, Generator 손실함수(g_loss): 1.992107, Discriminator 손실함수 (d_loss): 0.820542
# 반복(Epoch) : 23800, Generator 손실함수(g_loss): 2.363426, Discriminator 손실함수 (d_loss): 0.807682
# 반복(Epoch) : 23900, Generator 손실함수(g_loss): 1.977397, Discriminator 손실함수 (d_loss): 0.763460
# 반복(Epoch) : 24000, Generator 손실함수(g_loss): 1.776958, Discriminator 손실함수 (d_loss): 0.886791
# 반복(Epoch) : 24100, Generator 손실함수(g_loss): 2.656333, Discriminator 손실함수 (d_loss): 0.658772
# 반복(Epoch) : 24200, Generator 손실함수(g_loss): 2.119027, Discriminator 손실함수 (d_loss): 0.747846
# 반복(Epoch) : 24300, Generator 손실함수(g_loss): 1.901441, Discriminator 손실함수 (d_loss): 0.822387
# 반복(Epoch) : 24400, Generator 손실함수(g_loss): 2.336281, Discriminator 손실함수 (d_loss): 0.829809
# 반복(Epoch) : 24500, Generator 손실함수(g_loss): 2.255606, Discriminator 손실함수 (d_loss): 0.642033
# 반복(Epoch) : 24600, Generator 손실함수(g_loss): 1.797187, Discriminator 손실함수 (d_loss): 0.940197
# 반복(Epoch) : 24700, Generator 손실함수(g_loss): 1.828141, Discriminator 손실함수 (d_loss): 0.792033
# 반복(Epoch) : 24800, Generator 손실함수(g_loss): 2.064057, Discriminator 손실함수 (d_loss): 0.699764
# 반복(Epoch) : 24900, Generator 손실함수(g_loss): 2.557096, Discriminator 손실함수 (d_loss): 0.544321
# 반복(Epoch) : 25000, Generator 손실함수(g_loss): 2.114241, Discriminator 손실함수 (d_loss): 0.543667
# 반복(Epoch) : 25100, Generator 손실함수(g_loss): 2.267764, Discriminator 손실함수 (d_loss): 0.588227
# 반복(Epoch) : 25200, Generator 손실함수(g_loss): 2.041787, Discriminator 손실함수 (d_loss): 0.838649
# 반복(Epoch) : 25300, Generator 손실함수(g_loss): 2.290768, Discriminator 손실함수 (d_loss): 0.724939
# 반복(Epoch) : 25400, Generator 손실함수(g_loss): 2.005072, Discriminator 손실함수 (d_loss): 0.590524
# 반복(Epoch) : 25500, Generator 손실함수(g_loss): 2.108443, Discriminator 손실함수 (d_loss): 0.724380
# 반복(Epoch) : 25600, Generator 손실함수(g_loss): 1.948358, Discriminator 손실함수 (d_loss): 0.822315
# 반복(Epoch) : 25700, Generator 손실함수(g_loss): 1.978801, Discriminator 손실함수 (d_loss): 0.719402
# 반복(Epoch) : 25800, Generator 손실함수(g_loss): 2.002769, Discriminator 손실함수 (d_loss): 0.807787
# 반복(Epoch) : 25900, Generator 손실함수(g_loss): 2.248859, Discriminator 손실함수 (d_loss): 0.699840
# 반복(Epoch) : 26000, Generator 손실함수(g_loss): 2.118797, Discriminator 손실함수 (d_loss): 0.864366
# 반복(Epoch) : 26100, Generator 손실함수(g_loss): 2.385391, Discriminator 손실함수 (d_loss): 0.671035
# 반복(Epoch) : 26200, Generator 손실함수(g_loss): 2.004700, Discriminator 손실함수 (d_loss): 0.735718
# 반복(Epoch) : 26300, Generator 손실함수(g_loss): 1.980981, Discriminator 손실함수 (d_loss): 0.826651
# 반복(Epoch) : 26400, Generator 손실함수(g_loss): 2.208124, Discriminator 손실함수 (d_loss): 0.639243
# 반복(Epoch) : 26500, Generator 손실함수(g_loss): 2.197684, Discriminator 손실함수 (d_loss): 0.638469
# 반복(Epoch) : 26600, Generator 손실함수(g_loss): 1.931630, Discriminator 손실함수 (d_loss): 0.675620
# 반복(Epoch) : 26700, Generator 손실함수(g_loss): 2.238668, Discriminator 손실함수 (d_loss): 0.891354
# 반복(Epoch) : 26800, Generator 손실함수(g_loss): 2.057458, Discriminator 손실함수 (d_loss): 0.722388
# 반복(Epoch) : 26900, Generator 손실함수(g_loss): 2.180956, Discriminator 손실함수 (d_loss): 0.696603
# 반복(Epoch) : 27000, Generator 손실함수(g_loss): 2.269661, Discriminator 손실함수 (d_loss): 0.697402
# 반복(Epoch) : 27100, Generator 손실함수(g_loss): 2.122413, Discriminator 손실함수 (d_loss): 0.865859
# 반복(Epoch) : 27200, Generator 손실함수(g_loss): 2.205561, Discriminator 손실함수 (d_loss): 0.707125
# 반복(Epoch) : 27300, Generator 손실함수(g_loss): 2.113278, Discriminator 손실함수 (d_loss): 0.788087
# 반복(Epoch) : 27400, Generator 손실함수(g_loss): 2.161195, Discriminator 손실함수 (d_loss): 0.918375
# 반복(Epoch) : 27500, Generator 손실함수(g_loss): 2.090251, Discriminator 손실함수 (d_loss): 0.796407
# 반복(Epoch) : 27600, Generator 손실함수(g_loss): 2.033167, Discriminator 손실함수 (d_loss): 0.749004
# 반복(Epoch) : 27700, Generator 손실함수(g_loss): 2.081146, Discriminator 손실함수 (d_loss): 0.831673
# 반복(Epoch) : 27800, Generator 손실함수(g_loss): 2.210650, Discriminator 손실함수 (d_loss): 0.731100
# 반복(Epoch) : 27900, Generator 손실함수(g_loss): 2.114697, Discriminator 손실함수 (d_loss): 0.829717
# 반복(Epoch) : 28000, Generator 손실함수(g_loss): 1.786404, Discriminator 손실함수 (d_loss): 0.823202
# 반복(Epoch) : 28100, Generator 손실함수(g_loss): 2.292615, Discriminator 손실함수 (d_loss): 0.671876
# 반복(Epoch) : 28200, Generator 손실함수(g_loss): 2.246746, Discriminator 손실함수 (d_loss): 0.980815
# 반복(Epoch) : 28300, Generator 손실함수(g_loss): 2.072944, Discriminator 손실함수 (d_loss): 0.638867
# 반복(Epoch) : 28400, Generator 손실함수(g_loss): 1.982492, Discriminator 손실함수 (d_loss): 0.804718
# 반복(Epoch) : 28500, Generator 손실함수(g_loss): 2.244913, Discriminator 손실함수 (d_loss): 0.676263
# 반복(Epoch) : 28600, Generator 손실함수(g_loss): 1.819741, Discriminator 손실함수 (d_loss): 0.844109
# 반복(Epoch) : 28700, Generator 손실함수(g_loss): 1.954720, Discriminator 손실함수 (d_loss): 0.935568
# 반복(Epoch) : 28800, Generator 손실함수(g_loss): 2.252504, Discriminator 손실함수 (d_loss): 0.701178
# 반복(Epoch) : 28900, Generator 손실함수(g_loss): 1.849258, Discriminator 손실함수 (d_loss): 0.864425
# 반복(Epoch) : 29000, Generator 손실함수(g_loss): 2.292513, Discriminator 손실함수 (d_loss): 0.540515
# 반복(Epoch) : 29100, Generator 손실함수(g_loss): 2.313187, Discriminator 손실함수 (d_loss): 0.746931
# 반복(Epoch) : 29200, Generator 손실함수(g_loss): 1.898256, Discriminator 손실함수 (d_loss): 0.865744
# 반복(Epoch) : 29300, Generator 손실함수(g_loss): 2.129734, Discriminator 손실함수 (d_loss): 0.653871
# 반복(Epoch) : 29400, Generator 손실함수(g_loss): 1.861019, Discriminator 손실함수 (d_loss): 0.671138
# 반복(Epoch) : 29500, Generator 손실함수(g_loss): 2.347322, Discriminator 손실함수 (d_loss): 0.778399
# 반복(Epoch) : 29600, Generator 손실함수(g_loss): 2.307236, Discriminator 손실함수 (d_loss): 0.566383
# 반복(Epoch) : 29700, Generator 손실함수(g_loss): 2.030739, Discriminator 손실함수 (d_loss): 0.652440
# 반복(Epoch) : 29800, Generator 손실함수(g_loss): 2.269912, Discriminator 손실함수 (d_loss): 0.702185
# 반복(Epoch) : 29900, Generator 손실함수(g_loss): 2.052262, Discriminator 손실함수 (d_loss): 0.724181
# 반복(Epoch) : 30000, Generator 손실함수(g_loss): 2.309581, Discriminator 손실함수 (d_loss): 0.737067
# 반복(Epoch) : 30100, Generator 손실함수(g_loss): 1.958559, Discriminator 손실함수 (d_loss): 0.783997
# 반복(Epoch) : 30200, Generator 손실함수(g_loss): 2.068480, Discriminator 손실함수 (d_loss): 0.893832
# 반복(Epoch) : 30300, Generator 손실함수(g_loss): 2.085678, Discriminator 손실함수 (d_loss): 0.658450
# 반복(Epoch) : 30400, Generator 손실함수(g_loss): 1.884351, Discriminator 손실함수 (d_loss): 0.818806
# 반복(Epoch) : 30500, Generator 손실함수(g_loss): 2.391903, Discriminator 손실함수 (d_loss): 0.549795
# 반복(Epoch) : 30600, Generator 손실함수(g_loss): 1.987847, Discriminator 손실함수 (d_loss): 0.993265
# 반복(Epoch) : 30700, Generator 손실함수(g_loss): 1.658105, Discriminator 손실함수 (d_loss): 0.781110
# 반복(Epoch) : 30800, Generator 손실함수(g_loss): 2.249706, Discriminator 손실함수 (d_loss): 0.685948
# 반복(Epoch) : 30900, Generator 손실함수(g_loss): 2.228082, Discriminator 손실함수 (d_loss): 0.701335
# 반복(Epoch) : 31000, Generator 손실함수(g_loss): 2.282628, Discriminator 손실함수 (d_loss): 0.579514
# 반복(Epoch) : 31100, Generator 손실함수(g_loss): 1.907964, Discriminator 손실함수 (d_loss): 0.639594
# 반복(Epoch) : 31200, Generator 손실함수(g_loss): 2.017006, Discriminator 손실함수 (d_loss): 0.765227
# 반복(Epoch) : 31300, Generator 손실함수(g_loss): 1.976381, Discriminator 손실함수 (d_loss): 0.700311
# 반복(Epoch) : 31400, Generator 손실함수(g_loss): 1.988705, Discriminator 손실함수 (d_loss): 0.672206
# 반복(Epoch) : 31500, Generator 손실함수(g_loss): 2.298370, Discriminator 손실함수 (d_loss): 0.645507
# 반복(Epoch) : 31600, Generator 손실함수(g_loss): 2.326265, Discriminator 손실함수 (d_loss): 0.668394
# 반복(Epoch) : 31700, Generator 손실함수(g_loss): 2.426678, Discriminator 손실함수 (d_loss): 0.759613
# 반복(Epoch) : 31800, Generator 손실함수(g_loss): 2.189951, Discriminator 손실함수 (d_loss): 0.683188
# 반복(Epoch) : 31900, Generator 손실함수(g_loss): 1.956167, Discriminator 손실함수 (d_loss): 0.876486
# 반복(Epoch) : 32000, Generator 손실함수(g_loss): 2.444958, Discriminator 손실함수 (d_loss): 0.648844
# 반복(Epoch) : 32100, Generator 손실함수(g_loss): 2.103848, Discriminator 손실함수 (d_loss): 0.705415
# 반복(Epoch) : 32200, Generator 손실함수(g_loss): 1.895332, Discriminator 손실함수 (d_loss): 0.682687
# 반복(Epoch) : 32300, Generator 손실함수(g_loss): 2.112309, Discriminator 손실함수 (d_loss): 0.677682
# 반복(Epoch) : 32400, Generator 손실함수(g_loss): 2.312362, Discriminator 손실함수 (d_loss): 0.794509
# 반복(Epoch) : 32500, Generator 손실함수(g_loss): 2.278237, Discriminator 손실함수 (d_loss): 0.806804
# 반복(Epoch) : 32600, Generator 손실함수(g_loss): 2.073207, Discriminator 손실함수 (d_loss): 0.663639
# 반복(Epoch) : 32700, Generator 손실함수(g_loss): 2.474827, Discriminator 손실함수 (d_loss): 0.583848
# 반복(Epoch) : 32800, Generator 손실함수(g_loss): 2.173459, Discriminator 손실함수 (d_loss): 0.800957
# 반복(Epoch) : 32900, Generator 손실함수(g_loss): 2.075046, Discriminator 손실함수 (d_loss): 0.679672
# 반복(Epoch) : 33000, Generator 손실함수(g_loss): 1.791073, Discriminator 손실함수 (d_loss): 0.789147
# 반복(Epoch) : 33100, Generator 손실함수(g_loss): 2.387205, Discriminator 손실함수 (d_loss): 0.598377
# 반복(Epoch) : 33200, Generator 손실함수(g_loss): 2.388311, Discriminator 손실함수 (d_loss): 0.698245
# 반복(Epoch) : 33300, Generator 손실함수(g_loss): 2.189519, Discriminator 손실함수 (d_loss): 0.820111
# 반복(Epoch) : 33400, Generator 손실함수(g_loss): 2.031308, Discriminator 손실함수 (d_loss): 0.633910
# 반복(Epoch) : 33500, Generator 손실함수(g_loss): 2.287077, Discriminator 손실함수 (d_loss): 0.739204
# 반복(Epoch) : 33600, Generator 손실함수(g_loss): 2.052605, Discriminator 손실함수 (d_loss): 0.614060
# 반복(Epoch) : 33700, Generator 손실함수(g_loss): 2.115329, Discriminator 손실함수 (d_loss): 0.789380
# 반복(Epoch) : 33800, Generator 손실함수(g_loss): 1.763707, Discriminator 손실함수 (d_loss): 0.784963
# 반복(Epoch) : 33900, Generator 손실함수(g_loss): 2.020680, Discriminator 손실함수 (d_loss): 0.790717
# 반복(Epoch) : 34000, Generator 손실함수(g_loss): 2.317358, Discriminator 손실함수 (d_loss): 0.688777
# 반복(Epoch) : 34100, Generator 손실함수(g_loss): 2.162917, Discriminator 손실함수 (d_loss): 0.829673
# 반복(Epoch) : 34200, Generator 손실함수(g_loss): 2.451481, Discriminator 손실함수 (d_loss): 0.610777
# 반복(Epoch) : 34300, Generator 손실함수(g_loss): 1.905824, Discriminator 손실함수 (d_loss): 0.862141
# 반복(Epoch) : 34400, Generator 손실함수(g_loss): 2.566855, Discriminator 손실함수 (d_loss): 0.658047
# 반복(Epoch) : 34500, Generator 손실함수(g_loss): 2.268809, Discriminator 손실함수 (d_loss): 0.650895
# 반복(Epoch) : 34600, Generator 손실함수(g_loss): 1.988990, Discriminator 손실함수 (d_loss): 0.836451
# 반복(Epoch) : 34700, Generator 손실함수(g_loss): 2.371642, Discriminator 손실함수 (d_loss): 0.783164
# 반복(Epoch) : 34800, Generator 손실함수(g_loss): 2.118554, Discriminator 손실함수 (d_loss): 0.769001
# 반복(Epoch) : 34900, Generator 손실함수(g_loss): 2.206621, Discriminator 손실함수 (d_loss): 0.840309
# 반복(Epoch) : 35000, Generator 손실함수(g_loss): 2.243177, Discriminator 손실함수 (d_loss): 0.954778
# 반복(Epoch) : 35100, Generator 손실함수(g_loss): 2.290434, Discriminator 손실함수 (d_loss): 0.699995
# 반복(Epoch) : 35200, Generator 손실함수(g_loss): 2.084854, Discriminator 손실함수 (d_loss): 0.617149
# 반복(Epoch) : 35300, Generator 손실함수(g_loss): 1.994535, Discriminator 손실함수 (d_loss): 0.854867
# 반복(Epoch) : 35400, Generator 손실함수(g_loss): 2.179294, Discriminator 손실함수 (d_loss): 0.727444
# 반복(Epoch) : 35500, Generator 손실함수(g_loss): 2.060458, Discriminator 손실함수 (d_loss): 0.612401
# 반복(Epoch) : 35600, Generator 손실함수(g_loss): 1.779867, Discriminator 손실함수 (d_loss): 0.776094
# 반복(Epoch) : 35700, Generator 손실함수(g_loss): 2.465390, Discriminator 손실함수 (d_loss): 0.625898
# 반복(Epoch) : 35800, Generator 손실함수(g_loss): 2.000599, Discriminator 손실함수 (d_loss): 1.011533
# 반복(Epoch) : 35900, Generator 손실함수(g_loss): 2.574480, Discriminator 손실함수 (d_loss): 0.648900
# 반복(Epoch) : 36000, Generator 손실함수(g_loss): 2.198104, Discriminator 손실함수 (d_loss): 0.682336
# 반복(Epoch) : 36100, Generator 손실함수(g_loss): 2.075381, Discriminator 손실함수 (d_loss): 0.762248
# 반복(Epoch) : 36200, Generator 손실함수(g_loss): 2.018683, Discriminator 손실함수 (d_loss): 0.812866
# 반복(Epoch) : 36300, Generator 손실함수(g_loss): 1.889863, Discriminator 손실함수 (d_loss): 0.626178
# 반복(Epoch) : 36400, Generator 손실함수(g_loss): 2.353229, Discriminator 손실함수 (d_loss): 0.735262
# 반복(Epoch) : 36500, Generator 손실함수(g_loss): 1.825249, Discriminator 손실함수 (d_loss): 0.763688
# 반복(Epoch) : 36600, Generator 손실함수(g_loss): 2.232000, Discriminator 손실함수 (d_loss): 0.658702
# 반복(Epoch) : 36700, Generator 손실함수(g_loss): 2.787002, Discriminator 손실함수 (d_loss): 0.546066
# 반복(Epoch) : 36800, Generator 손실함수(g_loss): 2.053409, Discriminator 손실함수 (d_loss): 0.916398
# 반복(Epoch) : 36900, Generator 손실함수(g_loss): 1.908503, Discriminator 손실함수 (d_loss): 0.815284
# 반복(Epoch) : 37000, Generator 손실함수(g_loss): 2.257708, Discriminator 손실함수 (d_loss): 0.688110
# 반복(Epoch) : 37100, Generator 손실함수(g_loss): 2.246976, Discriminator 손실함수 (d_loss): 0.619005
# 반복(Epoch) : 37200, Generator 손실함수(g_loss): 1.952052, Discriminator 손실함수 (d_loss): 0.827304
# 반복(Epoch) : 37300, Generator 손실함수(g_loss): 2.138896, Discriminator 손실함수 (d_loss): 0.756690
# 반복(Epoch) : 37400, Generator 손실함수(g_loss): 2.127094, Discriminator 손실함수 (d_loss): 0.682686
# 반복(Epoch) : 37500, Generator 손실함수(g_loss): 1.861131, Discriminator 손실함수 (d_loss): 0.800375
# 반복(Epoch) : 37600, Generator 손실함수(g_loss): 2.190736, Discriminator 손실함수 (d_loss): 0.527420
# 반복(Epoch) : 37700, Generator 손실함수(g_loss): 2.495997, Discriminator 손실함수 (d_loss): 0.622967
# 반복(Epoch) : 37800, Generator 손실함수(g_loss): 2.138843, Discriminator 손실함수 (d_loss): 0.649922
# 반복(Epoch) : 37900, Generator 손실함수(g_loss): 2.178567, Discriminator 손실함수 (d_loss): 0.809406
# 반복(Epoch) : 38000, Generator 손실함수(g_loss): 2.112102, Discriminator 손실함수 (d_loss): 0.719031
# 반복(Epoch) : 38100, Generator 손실함수(g_loss): 2.159392, Discriminator 손실함수 (d_loss): 0.551043
# 반복(Epoch) : 38200, Generator 손실함수(g_loss): 2.100399, Discriminator 손실함수 (d_loss): 0.682039
# 반복(Epoch) : 38300, Generator 손실함수(g_loss): 1.851365, Discriminator 손실함수 (d_loss): 0.563323
# 반복(Epoch) : 38400, Generator 손실함수(g_loss): 2.389802, Discriminator 손실함수 (d_loss): 0.766705
# 반복(Epoch) : 38500, Generator 손실함수(g_loss): 2.131388, Discriminator 손실함수 (d_loss): 0.544723
# 반복(Epoch) : 38600, Generator 손실함수(g_loss): 2.188726, Discriminator 손실함수 (d_loss): 0.715719
# 반복(Epoch) : 38700, Generator 손실함수(g_loss): 2.250202, Discriminator 손실함수 (d_loss): 0.772828
# 반복(Epoch) : 38800, Generator 손실함수(g_loss): 2.281959, Discriminator 손실함수 (d_loss): 0.840289
# 반복(Epoch) : 38900, Generator 손실함수(g_loss): 2.176044, Discriminator 손실함수 (d_loss): 0.747891
# 반복(Epoch) : 39000, Generator 손실함수(g_loss): 1.935468, Discriminator 손실함수 (d_loss): 0.682305
# 반복(Epoch) : 39100, Generator 손실함수(g_loss): 2.117953, Discriminator 손실함수 (d_loss): 0.822713
# 반복(Epoch) : 39200, Generator 손실함수(g_loss): 2.435999, Discriminator 손실함수 (d_loss): 0.706789
# 반복(Epoch) : 39300, Generator 손실함수(g_loss): 2.185548, Discriminator 손실함수 (d_loss): 0.676829
# 반복(Epoch) : 39400, Generator 손실함수(g_loss): 2.396273, Discriminator 손실함수 (d_loss): 0.749566
# 반복(Epoch) : 39500, Generator 손실함수(g_loss): 2.139750, Discriminator 손실함수 (d_loss): 0.870510
# 반복(Epoch) : 39600, Generator 손실함수(g_loss): 2.318337, Discriminator 손실함수 (d_loss): 0.651922
# 반복(Epoch) : 39700, Generator 손실함수(g_loss): 2.581252, Discriminator 손실함수 (d_loss): 0.524132
# 반복(Epoch) : 39800, Generator 손실함수(g_loss): 2.166222, Discriminator 손실함수 (d_loss): 0.767469
# 반복(Epoch) : 39900, Generator 손실함수(g_loss): 2.500798, Discriminator 손실함수 (d_loss): 0.555785
# 반복(Epoch) : 40000, Generator 손실함수(g_loss): 2.499663, Discriminator 손실함수 (d_loss): 0.506855
# 반복(Epoch) : 40100, Generator 손실함수(g_loss): 2.311020, Discriminator 손실함수 (d_loss): 0.676703
# 반복(Epoch) : 40200, Generator 손실함수(g_loss): 2.152671, Discriminator 손실함수 (d_loss): 0.753529
# 반복(Epoch) : 40300, Generator 손실함수(g_loss): 2.123072, Discriminator 손실함수 (d_loss): 0.785468
# 반복(Epoch) : 40400, Generator 손실함수(g_loss): 2.237700, Discriminator 손실함수 (d_loss): 0.658873
# 반복(Epoch) : 40500, Generator 손실함수(g_loss): 1.953496, Discriminator 손실함수 (d_loss): 0.708182
# 반복(Epoch) : 40600, Generator 손실함수(g_loss): 2.412573, Discriminator 손실함수 (d_loss): 0.581206
# 반복(Epoch) : 40700, Generator 손실함수(g_loss): 2.111795, Discriminator 손실함수 (d_loss): 0.795566
# 반복(Epoch) : 40800, Generator 손실함수(g_loss): 2.176270, Discriminator 손실함수 (d_loss): 0.635991
# 반복(Epoch) : 40900, Generator 손실함수(g_loss): 2.452667, Discriminator 손실함수 (d_loss): 0.646746
# 반복(Epoch) : 41000, Generator 손실함수(g_loss): 2.200265, Discriminator 손실함수 (d_loss): 0.633012
# 반복(Epoch) : 41100, Generator 손실함수(g_loss): 2.291843, Discriminator 손실함수 (d_loss): 0.463031
# 반복(Epoch) : 41200, Generator 손실함수(g_loss): 2.140811, Discriminator 손실함수 (d_loss): 0.548757
# 반복(Epoch) : 41300, Generator 손실함수(g_loss): 2.209428, Discriminator 손실함수 (d_loss): 0.521753
# 반복(Epoch) : 41400, Generator 손실함수(g_loss): 2.279073, Discriminator 손실함수 (d_loss): 0.589212
# 반복(Epoch) : 41500, Generator 손실함수(g_loss): 2.186758, Discriminator 손실함수 (d_loss): 0.547316
# 반복(Epoch) : 41600, Generator 손실함수(g_loss): 2.084370, Discriminator 손실함수 (d_loss): 0.822245
# 반복(Epoch) : 41700, Generator 손실함수(g_loss): 2.512261, Discriminator 손실함수 (d_loss): 0.619141
# 반복(Epoch) : 41800, Generator 손실함수(g_loss): 2.289271, Discriminator 손실함수 (d_loss): 0.646573
# 반복(Epoch) : 41900, Generator 손실함수(g_loss): 2.897898, Discriminator 손실함수 (d_loss): 0.612341
# 반복(Epoch) : 42000, Generator 손실함수(g_loss): 2.171184, Discriminator 손실함수 (d_loss): 0.828351
# 반복(Epoch) : 42100, Generator 손실함수(g_loss): 2.020834, Discriminator 손실함수 (d_loss): 0.677756
# 반복(Epoch) : 42200, Generator 손실함수(g_loss): 2.505136, Discriminator 손실함수 (d_loss): 0.525394
# 반복(Epoch) : 42300, Generator 손실함수(g_loss): 2.196528, Discriminator 손실함수 (d_loss): 0.779559
# 반복(Epoch) : 42400, Generator 손실함수(g_loss): 2.130559, Discriminator 손실함수 (d_loss): 0.603002
# 반복(Epoch) : 42500, Generator 손실함수(g_loss): 2.453392, Discriminator 손실함수 (d_loss): 0.627639
# 반복(Epoch) : 42600, Generator 손실함수(g_loss): 2.346306, Discriminator 손실함수 (d_loss): 0.634376
# 반복(Epoch) : 42700, Generator 손실함수(g_loss): 2.125594, Discriminator 손실함수 (d_loss): 0.680174
# 반복(Epoch) : 42800, Generator 손실함수(g_loss): 1.839838, Discriminator 손실함수 (d_loss): 0.573055
# 반복(Epoch) : 42900, Generator 손실함수(g_loss): 1.916691, Discriminator 손실함수 (d_loss): 0.770315
# 반복(Epoch) : 43000, Generator 손실함수(g_loss): 1.891274, Discriminator 손실함수 (d_loss): 0.802428
# 반복(Epoch) : 43100, Generator 손실함수(g_loss): 2.021037, Discriminator 손실함수 (d_loss): 0.727618
# 반복(Epoch) : 43200, Generator 손실함수(g_loss): 2.261725, Discriminator 손실함수 (d_loss): 0.565675
# 반복(Epoch) : 43300, Generator 손실함수(g_loss): 2.402782, Discriminator 손실함수 (d_loss): 0.611691
# 반복(Epoch) : 43400, Generator 손실함수(g_loss): 2.576153, Discriminator 손실함수 (d_loss): 0.611831
# 반복(Epoch) : 43500, Generator 손실함수(g_loss): 2.266290, Discriminator 손실함수 (d_loss): 0.555017
# 반복(Epoch) : 43600, Generator 손실함수(g_loss): 2.518590, Discriminator 손실함수 (d_loss): 0.494406
# 반복(Epoch) : 43700, Generator 손실함수(g_loss): 2.272060, Discriminator 손실함수 (d_loss): 0.609648
# 반복(Epoch) : 43800, Generator 손실함수(g_loss): 2.186884, Discriminator 손실함수 (d_loss): 0.647367
# 반복(Epoch) : 43900, Generator 손실함수(g_loss): 2.488624, Discriminator 손실함수 (d_loss): 0.585198
# 반복(Epoch) : 44000, Generator 손실함수(g_loss): 1.802598, Discriminator 손실함수 (d_loss): 0.828006
# 반복(Epoch) : 44100, Generator 손실함수(g_loss): 2.532760, Discriminator 손실함수 (d_loss): 0.763241
# 반복(Epoch) : 44200, Generator 손실함수(g_loss): 2.421000, Discriminator 손실함수 (d_loss): 0.663394
# 반복(Epoch) : 44300, Generator 손실함수(g_loss): 2.141056, Discriminator 손실함수 (d_loss): 0.824968
# 반복(Epoch) : 44400, Generator 손실함수(g_loss): 2.562465, Discriminator 손실함수 (d_loss): 0.575824
# 반복(Epoch) : 44500, Generator 손실함수(g_loss): 2.460593, Discriminator 손실함수 (d_loss): 0.626792
# 반복(Epoch) : 44600, Generator 손실함수(g_loss): 2.075037, Discriminator 손실함수 (d_loss): 0.695546
# 반복(Epoch) : 44700, Generator 손실함수(g_loss): 2.603344, Discriminator 손실함수 (d_loss): 0.457387
# 반복(Epoch) : 44800, Generator 손실함수(g_loss): 2.080087, Discriminator 손실함수 (d_loss): 0.529399
# 반복(Epoch) : 44900, Generator 손실함수(g_loss): 2.117096, Discriminator 손실함수 (d_loss): 0.662890
# 반복(Epoch) : 45000, Generator 손실함수(g_loss): 2.297354, Discriminator 손실함수 (d_loss): 0.610339
# 반복(Epoch) : 45100, Generator 손실함수(g_loss): 2.193398, Discriminator 손실함수 (d_loss): 0.531877
# 반복(Epoch) : 45200, Generator 손실함수(g_loss): 2.170277, Discriminator 손실함수 (d_loss): 0.622497
# 반복(Epoch) : 45300, Generator 손실함수(g_loss): 2.198020, Discriminator 손실함수 (d_loss): 0.629186
# 반복(Epoch) : 45400, Generator 손실함수(g_loss): 2.461172, Discriminator 손실함수 (d_loss): 0.635395
# 반복(Epoch) : 45500, Generator 손실함수(g_loss): 2.080717, Discriminator 손실함수 (d_loss): 0.560027
# 반복(Epoch) : 45600, Generator 손실함수(g_loss): 2.731395, Discriminator 손실함수 (d_loss): 0.539148
# 반복(Epoch) : 45700, Generator 손실함수(g_loss): 2.656345, Discriminator 손실함수 (d_loss): 0.835705
# 반복(Epoch) : 45800, Generator 손실함수(g_loss): 2.496273, Discriminator 손실함수 (d_loss): 0.672212
# 반복(Epoch) : 45900, Generator 손실함수(g_loss): 2.398327, Discriminator 손실함수 (d_loss): 0.640355
# 반복(Epoch) : 46000, Generator 손실함수(g_loss): 2.897284, Discriminator 손실함수 (d_loss): 0.691719
# 반복(Epoch) : 46100, Generator 손실함수(g_loss): 2.274981, Discriminator 손실함수 (d_loss): 0.653841
# 반복(Epoch) : 46200, Generator 손실함수(g_loss): 2.294278, Discriminator 손실함수 (d_loss): 0.697660
# 반복(Epoch) : 46300, Generator 손실함수(g_loss): 2.544463, Discriminator 손실함수 (d_loss): 0.715888
# 반복(Epoch) : 46400, Generator 손실함수(g_loss): 2.643151, Discriminator 손실함수 (d_loss): 0.643159
# 반복(Epoch) : 46500, Generator 손실함수(g_loss): 2.570135, Discriminator 손실함수 (d_loss): 0.674683
# 반복(Epoch) : 46600, Generator 손실함수(g_loss): 2.651534, Discriminator 손실함수 (d_loss): 0.568912
# 반복(Epoch) : 46700, Generator 손실함수(g_loss): 2.792320, Discriminator 손실함수 (d_loss): 0.618730
# 반복(Epoch) : 46800, Generator 손실함수(g_loss): 2.123844, Discriminator 손실함수 (d_loss): 0.606824
# 반복(Epoch) : 46900, Generator 손실함수(g_loss): 1.956565, Discriminator 손실함수 (d_loss): 0.748299
# 반복(Epoch) : 47000, Generator 손실함수(g_loss): 2.396450, Discriminator 손실함수 (d_loss): 0.806296
# 반복(Epoch) : 47100, Generator 손실함수(g_loss): 2.685237, Discriminator 손실함수 (d_loss): 0.492562
# 반복(Epoch) : 47200, Generator 손실함수(g_loss): 2.420050, Discriminator 손실함수 (d_loss): 0.618437
# 반복(Epoch) : 47300, Generator 손실함수(g_loss): 2.010638, Discriminator 손실함수 (d_loss): 0.629982
# 반복(Epoch) : 47400, Generator 손실함수(g_loss): 2.206819, Discriminator 손실함수 (d_loss): 0.519069
# 반복(Epoch) : 47500, Generator 손실함수(g_loss): 2.474506, Discriminator 손실함수 (d_loss): 0.651902
# 반복(Epoch) : 47600, Generator 손실함수(g_loss): 1.838553, Discriminator 손실함수 (d_loss): 0.726178
# 반복(Epoch) : 47700, Generator 손실함수(g_loss): 2.267482, Discriminator 손실함수 (d_loss): 0.552991
# 반복(Epoch) : 47800, Generator 손실함수(g_loss): 2.280570, Discriminator 손실함수 (d_loss): 0.621608
# 반복(Epoch) : 47900, Generator 손실함수(g_loss): 2.133996, Discriminator 손실함수 (d_loss): 0.541896
# 반복(Epoch) : 48000, Generator 손실함수(g_loss): 2.357080, Discriminator 손실함수 (d_loss): 0.697769
# 반복(Epoch) : 48100, Generator 손실함수(g_loss): 2.242037, Discriminator 손실함수 (d_loss): 0.700897
# 반복(Epoch) : 48200, Generator 손실함수(g_loss): 2.183988, Discriminator 손실함수 (d_loss): 0.703778
# 반복(Epoch) : 48300, Generator 손실함수(g_loss): 2.516791, Discriminator 손실함수 (d_loss): 0.483187
# 반복(Epoch) : 48400, Generator 손실함수(g_loss): 2.237011, Discriminator 손실함수 (d_loss): 0.614072
# 반복(Epoch) : 48500, Generator 손실함수(g_loss): 2.285182, Discriminator 손실함수 (d_loss): 0.739491
# 반복(Epoch) : 48600, Generator 손실함수(g_loss): 2.608554, Discriminator 손실함수 (d_loss): 0.520571
# 반복(Epoch) : 48700, Generator 손실함수(g_loss): 2.406760, Discriminator 손실함수 (d_loss): 0.608509
# 반복(Epoch) : 48800, Generator 손실함수(g_loss): 1.991292, Discriminator 손실함수 (d_loss): 0.772207
# 반복(Epoch) : 48900, Generator 손실함수(g_loss): 2.295108, Discriminator 손실함수 (d_loss): 0.639264
# 반복(Epoch) : 49000, Generator 손실함수(g_loss): 2.597594, Discriminator 손실함수 (d_loss): 0.635075
# 반복(Epoch) : 49100, Generator 손실함수(g_loss): 2.266565, Discriminator 손실함수 (d_loss): 0.603800
# 반복(Epoch) : 49200, Generator 손실함수(g_loss): 2.402555, Discriminator 손실함수 (d_loss): 0.634339
# 반복(Epoch) : 49300, Generator 손실함수(g_loss): 2.345401, Discriminator 손실함수 (d_loss): 0.737083
# 반복(Epoch) : 49400, Generator 손실함수(g_loss): 2.313511, Discriminator 손실함수 (d_loss): 0.638536
# 반복(Epoch) : 49500, Generator 손실함수(g_loss): 2.386822, Discriminator 손실함수 (d_loss): 0.605402
# 반복(Epoch) : 49600, Generator 손실함수(g_loss): 2.591933, Discriminator 손실함수 (d_loss): 0.678404
# 반복(Epoch) : 49700, Generator 손실함수(g_loss): 2.586271, Discriminator 손실함수 (d_loss): 0.666001
# 반복(Epoch) : 49800, Generator 손실함수(g_loss): 2.030197, Discriminator 손실함수 (d_loss): 0.660854
# 반복(Epoch) : 49900, Generator 손실함수(g_loss): 2.430438, Discriminator 손실함수 (d_loss): 0.552077
# 반복(Epoch) : 50000, Generator 손실함수(g_loss): 2.112814, Discriminator 손실함수 (d_loss): 0.642916
# 반복(Epoch) : 50100, Generator 손실함수(g_loss): 2.040821, Discriminator 손실함수 (d_loss): 0.723464
# 반복(Epoch) : 50200, Generator 손실함수(g_loss): 2.700044, Discriminator 손실함수 (d_loss): 0.562886
# 반복(Epoch) : 50300, Generator 손실함수(g_loss): 2.439756, Discriminator 손실함수 (d_loss): 0.614998
# 반복(Epoch) : 50400, Generator 손실함수(g_loss): 2.181150, Discriminator 손실함수 (d_loss): 0.706179
# 반복(Epoch) : 50500, Generator 손실함수(g_loss): 2.315536, Discriminator 손실함수 (d_loss): 0.629940
# 반복(Epoch) : 50600, Generator 손실함수(g_loss): 2.185415, Discriminator 손실함수 (d_loss): 0.642110
# 반복(Epoch) : 50700, Generator 손실함수(g_loss): 2.076869, Discriminator 손실함수 (d_loss): 0.720861
# 반복(Epoch) : 50800, Generator 손실함수(g_loss): 2.407768, Discriminator 손실함수 (d_loss): 0.716863
# 반복(Epoch) : 50900, Generator 손실함수(g_loss): 2.227173, Discriminator 손실함수 (d_loss): 0.658399
# 반복(Epoch) : 51000, Generator 손실함수(g_loss): 2.123209, Discriminator 손실함수 (d_loss): 0.569226
# 반복(Epoch) : 51100, Generator 손실함수(g_loss): 2.411124, Discriminator 손실함수 (d_loss): 0.606639
# 반복(Epoch) : 51200, Generator 손실함수(g_loss): 2.201935, Discriminator 손실함수 (d_loss): 0.797840
# 반복(Epoch) : 51300, Generator 손실함수(g_loss): 1.736158, Discriminator 손실함수 (d_loss): 0.748465
# 반복(Epoch) : 51400, Generator 손실함수(g_loss): 2.434350, Discriminator 손실함수 (d_loss): 0.502870
# 반복(Epoch) : 51500, Generator 손실함수(g_loss): 2.376976, Discriminator 손실함수 (d_loss): 0.636068
# 반복(Epoch) : 51600, Generator 손실함수(g_loss): 2.677742, Discriminator 손실함수 (d_loss): 0.488646
# 반복(Epoch) : 51700, Generator 손실함수(g_loss): 2.379706, Discriminator 손실함수 (d_loss): 0.801924
# 반복(Epoch) : 51800, Generator 손실함수(g_loss): 2.539954, Discriminator 손실함수 (d_loss): 0.760433
# 반복(Epoch) : 51900, Generator 손실함수(g_loss): 2.412936, Discriminator 손실함수 (d_loss): 0.847625
# 반복(Epoch) : 52000, Generator 손실함수(g_loss): 2.171280, Discriminator 손실함수 (d_loss): 0.632066
# 반복(Epoch) : 52100, Generator 손실함수(g_loss): 2.138478, Discriminator 손실함수 (d_loss): 0.581259
# 반복(Epoch) : 52200, Generator 손실함수(g_loss): 1.853581, Discriminator 손실함수 (d_loss): 0.764633
# 반복(Epoch) : 52300, Generator 손실함수(g_loss): 2.192527, Discriminator 손실함수 (d_loss): 0.566011
# 반복(Epoch) : 52400, Generator 손실함수(g_loss): 2.417609, Discriminator 손실함수 (d_loss): 0.407912
# 반복(Epoch) : 52500, Generator 손실함수(g_loss): 2.584291, Discriminator 손실함수 (d_loss): 0.620332
# 반복(Epoch) : 52600, Generator 손실함수(g_loss): 2.308741, Discriminator 손실함수 (d_loss): 0.659119
# 반복(Epoch) : 52700, Generator 손실함수(g_loss): 2.452099, Discriminator 손실함수 (d_loss): 0.709475
# ...
# 반복(Epoch) : 82500, Generator 손실함수(g_loss): 2.531169, Discriminator 손실함수 (d_loss): 0.546501
# 반복(Epoch) : 82600, Generator 손실함수(g_loss): 2.047950, Discriminator 손실함수 (d_loss): 0.505608
# 반복(Epoch) : 82700, Generator 손실함수(g_loss): 2.866583, Discriminator 손실함수 (d_loss): 0.460921
# 반복(Epoch) : 82800, Generator 손실함수(g_loss): 1.902085, Discriminator 손실함수 (d_loss): 0.596057
# 반복(Epoch) : 82900, Generator 손실함수(g_loss): 2.243006, Discriminator 손실함수 (d_loss): 0.578133
# 반복(Epoch) : 83000, Generator 손실함수(g_loss): 2.207325, Discriminator 손실함수 (d_loss): 0.560017
# 반복(Epoch) : 83100, Generator 손실함수(g_loss): 2.246453, Discriminator 손실함수 (d_loss): 0.670641
# 반복(Epoch) : 83200, Generator 손실함수(g_loss): 2.555713, Discriminator 손실함수 (d_loss): 0.376754
# 반복(Epoch) : 83300, Generator 손실함수(g_loss): 2.617579, Discriminator 손실함수 (d_loss): 0.588395
# 반복(Epoch) : 83400, Generator 손실함수(g_loss): 2.592770, Discriminator 손실함수 (d_loss): 0.486862
# 반복(Epoch) : 83500, Generator 손실함수(g_loss): 2.769677, Discriminator 손실함수 (d_loss): 0.498123
# 반복(Epoch) : 83600, Generator 손실함수(g_loss): 2.819307, Discriminator 손실함수 (d_loss): 0.495784
# 반복(Epoch) : 83700, Generator 손실함수(g_loss): 2.268178, Discriminator 손실함수 (d_loss): 0.853975
# 반복(Epoch) : 83800, Generator 손실함수(g_loss): 2.953044, Discriminator 손실함수 (d_loss): 0.375220
# 반복(Epoch) : 83900, Generator 손실함수(g_loss): 2.295773, Discriminator 손실함수 (d_loss): 0.522688
# 반복(Epoch) : 84000, Generator 손실함수(g_loss): 2.557814, Discriminator 손실함수 (d_loss): 0.412484
# 반복(Epoch) : 84100, Generator 손실함수(g_loss): 2.520638, Discriminator 손실함수 (d_loss): 0.459133
# 반복(Epoch) : 84200, Generator 손실함수(g_loss): 2.197579, Discriminator 손실함수 (d_loss): 0.687883
# 반복(Epoch) : 84300, Generator 손실함수(g_loss): 2.487692, Discriminator 손실함수 (d_loss): 0.513222
# 반복(Epoch) : 84400, Generator 손실함수(g_loss): 2.187538, Discriminator 손실함수 (d_loss): 0.498171
# 반복(Epoch) : 84500, Generator 손실함수(g_loss): 2.380210, Discriminator 손실함수 (d_loss): 0.469084
# 반복(Epoch) : 84600, Generator 손실함수(g_loss): 2.646834, Discriminator 손실함수 (d_loss): 0.525352
# 반복(Epoch) : 84700, Generator 손실함수(g_loss): 2.736217, Discriminator 손실함수 (d_loss): 0.447704
# 반복(Epoch) : 84800, Generator 손실함수(g_loss): 2.612005, Discriminator 손실함수 (d_loss): 0.666870
# 반복(Epoch) : 84900, Generator 손실함수(g_loss): 2.695412, Discriminator 손실함수 (d_loss): 0.540937
# 반복(Epoch) : 85000, Generator 손실함수(g_loss): 2.485263, Discriminator 손실함수 (d_loss): 0.546159
# 반복(Epoch) : 85100, Generator 손실함수(g_loss): 2.389794, Discriminator 손실함수 (d_loss): 0.534953
# 반복(Epoch) : 85200, Generator 손실함수(g_loss): 2.533005, Discriminator 손실함수 (d_loss): 0.601223
# 반복(Epoch) : 85300, Generator 손실함수(g_loss): 2.389868, Discriminator 손실함수 (d_loss): 0.380837
# 반복(Epoch) : 85400, Generator 손실함수(g_loss): 2.046180, Discriminator 손실함수 (d_loss): 0.586649
# 반복(Epoch) : 85500, Generator 손실함수(g_loss): 2.233613, Discriminator 손실함수 (d_loss): 0.600694
# 반복(Epoch) : 85600, Generator 손실함수(g_loss): 2.001321, Discriminator 손실함수 (d_loss): 0.767206
# 반복(Epoch) : 85700, Generator 손실함수(g_loss): 2.154663, Discriminator 손실함수 (d_loss): 0.567066
# 반복(Epoch) : 85800, Generator 손실함수(g_loss): 2.400998, Discriminator 손실함수 (d_loss): 0.728069
# 반복(Epoch) : 85900, Generator 손실함수(g_loss): 2.242937, Discriminator 손실함수 (d_loss): 0.629255
# 반복(Epoch) : 86000, Generator 손실함수(g_loss): 2.383559, Discriminator 손실함수 (d_loss): 0.556715
# 반복(Epoch) : 86100, Generator 손실함수(g_loss): 2.434852, Discriminator 손실함수 (d_loss): 0.608361
# 반복(Epoch) : 86200, Generator 손실함수(g_loss): 2.182756, Discriminator 손실함수 (d_loss): 0.631554
# 반복(Epoch) : 86300, Generator 손실함수(g_loss): 1.991369, Discriminator 손실함수 (d_loss): 0.642700
# 반복(Epoch) : 86400, Generator 손실함수(g_loss): 2.014798, Discriminator 손실함수 (d_loss): 0.540058
# 반복(Epoch) : 86500, Generator 손실함수(g_loss): 2.474164, Discriminator 손실함수 (d_loss): 0.627866
# 반복(Epoch) : 86600, Generator 손실함수(g_loss): 2.547247, Discriminator 손실함수 (d_loss): 0.512535
# 반복(Epoch) : 86700, Generator 손실함수(g_loss): 2.288142, Discriminator 손실함수 (d_loss): 0.631579
# 반복(Epoch) : 86800, Generator 손실함수(g_loss): 2.421451, Discriminator 손실함수 (d_loss): 0.530660
# 반복(Epoch) : 86900, Generator 손실함수(g_loss): 2.592528, Discriminator 손실함수 (d_loss): 0.446815
# 반복(Epoch) : 87000, Generator 손실함수(g_loss): 2.444756, Discriminator 손실함수 (d_loss): 0.507710
# 반복(Epoch) : 87100, Generator 손실함수(g_loss): 2.541554, Discriminator 손실함수 (d_loss): 0.600079
# 반복(Epoch) : 87200, Generator 손실함수(g_loss): 2.390206, Discriminator 손실함수 (d_loss): 0.521093
# 반복(Epoch) : 87300, Generator 손실함수(g_loss): 2.670150, Discriminator 손실함수 (d_loss): 0.416351
# 반복(Epoch) : 87400, Generator 손실함수(g_loss): 2.477151, Discriminator 손실함수 (d_loss): 0.578874
# 반복(Epoch) : 87500, Generator 손실함수(g_loss): 2.468287, Discriminator 손실함수 (d_loss): 0.582044
# 반복(Epoch) : 87600, Generator 손실함수(g_loss): 2.265090, Discriminator 손실함수 (d_loss): 0.642906
# 반복(Epoch) : 87700, Generator 손실함수(g_loss): 2.385977, Discriminator 손실함수 (d_loss): 0.426737
# 반복(Epoch) : 87800, Generator 손실함수(g_loss): 2.463236, Discriminator 손실함수 (d_loss): 0.429456
# 반복(Epoch) : 87900, Generator 손실함수(g_loss): 2.792098, Discriminator 손실함수 (d_loss): 0.520600
# 반복(Epoch) : 88000, Generator 손실함수(g_loss): 2.460768, Discriminator 손실함수 (d_loss): 0.323635
# 반복(Epoch) : 88100, Generator 손실함수(g_loss): 2.368455, Discriminator 손실함수 (d_loss): 0.571211
# 반복(Epoch) : 88200, Generator 손실함수(g_loss): 2.365855, Discriminator 손실함수 (d_loss): 0.483602
# 반복(Epoch) : 88300, Generator 손실함수(g_loss): 2.543295, Discriminator 손실함수 (d_loss): 0.535003
# 반복(Epoch) : 88400, Generator 손실함수(g_loss): 2.485079, Discriminator 손실함수 (d_loss): 0.392384
# 반복(Epoch) : 88500, Generator 손실함수(g_loss): 2.226799, Discriminator 손실함수 (d_loss): 0.589669
# 반복(Epoch) : 88600, Generator 손실함수(g_loss): 2.708099, Discriminator 손실함수 (d_loss): 0.486204
# 반복(Epoch) : 88700, Generator 손실함수(g_loss): 2.126114, Discriminator 손실함수 (d_loss): 0.633908
# 반복(Epoch) : 88800, Generator 손실함수(g_loss): 2.603380, Discriminator 손실함수 (d_loss): 0.475708
# 반복(Epoch) : 88900, Generator 손실함수(g_loss): 2.458816, Discriminator 손실함수 (d_loss): 0.534407
# 반복(Epoch) : 89000, Generator 손실함수(g_loss): 2.246038, Discriminator 손실함수 (d_loss): 0.623933
# 반복(Epoch) : 89100, Generator 손실함수(g_loss): 2.070329, Discriminator 손실함수 (d_loss): 0.628965
# 반복(Epoch) : 89200, Generator 손실함수(g_loss): 2.507754, Discriminator 손실함수 (d_loss): 0.555691
# 반복(Epoch) : 89300, Generator 손실함수(g_loss): 2.454033, Discriminator 손실함수 (d_loss): 0.579991
# 반복(Epoch) : 89400, Generator 손실함수(g_loss): 2.653673, Discriminator 손실함수 (d_loss): 0.461896
# 반복(Epoch) : 89500, Generator 손실함수(g_loss): 2.439710, Discriminator 손실함수 (d_loss): 0.559957
# 반복(Epoch) : 89600, Generator 손실함수(g_loss): 2.393416, Discriminator 손실함수 (d_loss): 0.668715
# 반복(Epoch) : 89700, Generator 손실함수(g_loss): 2.324110, Discriminator 손실함수 (d_loss): 0.461771
# 반복(Epoch) : 89800, Generator 손실함수(g_loss): 2.404600, Discriminator 손실함수 (d_loss): 0.568626
# 반복(Epoch) : 89900, Generator 손실함수(g_loss): 2.443233, Discriminator 손실함수 (d_loss): 0.546063
# 반복(Epoch) : 90000, Generator 손실함수(g_loss): 2.668886, Discriminator 손실함수 (d_loss): 0.547231
# 반복(Epoch) : 90100, Generator 손실함수(g_loss): 2.272431, Discriminator 손실함수 (d_loss): 0.680700
# 반복(Epoch) : 90200, Generator 손실함수(g_loss): 2.155282, Discriminator 손실함수 (d_loss): 0.568439
# 반복(Epoch) : 90300, Generator 손실함수(g_loss): 2.255958, Discriminator 손실함수 (d_loss): 0.568327
# 반복(Epoch) : 90400, Generator 손실함수(g_loss): 2.871816, Discriminator 손실함수 (d_loss): 0.603358
# 반복(Epoch) : 90500, Generator 손실함수(g_loss): 2.741765, Discriminator 손실함수 (d_loss): 0.466683
# 반복(Epoch) : 90600, Generator 손실함수(g_loss): 2.686059, Discriminator 손실함수 (d_loss): 0.476563
# 반복(Epoch) : 90700, Generator 손실함수(g_loss): 2.419127, Discriminator 손실함수 (d_loss): 0.464564
# 반복(Epoch) : 90800, Generator 손실함수(g_loss): 2.307102, Discriminator 손실함수 (d_loss): 0.516224
# 반복(Epoch) : 90900, Generator 손실함수(g_loss): 2.576229, Discriminator 손실함수 (d_loss): 0.456663
# 반복(Epoch) : 91000, Generator 손실함수(g_loss): 2.723684, Discriminator 손실함수 (d_loss): 0.595127
# 반복(Epoch) : 91100, Generator 손실함수(g_loss): 2.825961, Discriminator 손실함수 (d_loss): 0.545109
# 반복(Epoch) : 91200, Generator 손실함수(g_loss): 2.378235, Discriminator 손실함수 (d_loss): 0.571456
# 반복(Epoch) : 91300, Generator 손실함수(g_loss): 2.672841, Discriminator 손실함수 (d_loss): 0.480229
# 반복(Epoch) : 91400, Generator 손실함수(g_loss): 2.506409, Discriminator 손실함수 (d_loss): 0.735263
# 반복(Epoch) : 91500, Generator 손실함수(g_loss): 2.121794, Discriminator 손실함수 (d_loss): 0.579857
# 반복(Epoch) : 91600, Generator 손실함수(g_loss): 2.442803, Discriminator 손실함수 (d_loss): 0.612690
# 반복(Epoch) : 91700, Generator 손실함수(g_loss): 3.021820, Discriminator 손실함수 (d_loss): 0.572127
# 반복(Epoch) : 91800, Generator 손실함수(g_loss): 2.311835, Discriminator 손실함수 (d_loss): 0.660911
# 반복(Epoch) : 91900, Generator 손실함수(g_loss): 2.930795, Discriminator 손실함수 (d_loss): 0.571094
# 반복(Epoch) : 92000, Generator 손실함수(g_loss): 2.706411, Discriminator 손실함수 (d_loss): 0.447632
# 반복(Epoch) : 92100, Generator 손실함수(g_loss): 3.098422, Discriminator 손실함수 (d_loss): 0.622290
# 반복(Epoch) : 92200, Generator 손실함수(g_loss): 2.532993, Discriminator 손실함수 (d_loss): 0.738154
# 반복(Epoch) : 92300, Generator 손실함수(g_loss): 2.699629, Discriminator 손실함수 (d_loss): 0.466367
# 반복(Epoch) : 92400, Generator 손실함수(g_loss): 2.402641, Discriminator 손실함수 (d_loss): 0.398554
# 반복(Epoch) : 92500, Generator 손실함수(g_loss): 2.403788, Discriminator 손실함수 (d_loss): 0.519581
# 반복(Epoch) : 92600, Generator 손실함수(g_loss): 2.673924, Discriminator 손실함수 (d_loss): 0.363557
# 반복(Epoch) : 92700, Generator 손실함수(g_loss): 2.380882, Discriminator 손실함수 (d_loss): 0.688965
# 반복(Epoch) : 92800, Generator 손실함수(g_loss): 2.066388, Discriminator 손실함수 (d_loss): 0.603236
# 반복(Epoch) : 92900, Generator 손실함수(g_loss): 2.677241, Discriminator 손실함수 (d_loss): 0.618740
# 반복(Epoch) : 93000, Generator 손실함수(g_loss): 2.147869, Discriminator 손실함수 (d_loss): 0.476033
# 반복(Epoch) : 93100, Generator 손실함수(g_loss): 2.286108, Discriminator 손실함수 (d_loss): 0.539885
# 반복(Epoch) : 93200, Generator 손실함수(g_loss): 2.266135, Discriminator 손실함수 (d_loss): 0.525195
# 반복(Epoch) : 93300, Generator 손실함수(g_loss): 2.912390, Discriminator 손실함수 (d_loss): 0.373396
# 반복(Epoch) : 93400, Generator 손실함수(g_loss): 2.692218, Discriminator 손실함수 (d_loss): 0.597074
# 반복(Epoch) : 93500, Generator 손실함수(g_loss): 2.401343, Discriminator 손실함수 (d_loss): 0.683320
# 반복(Epoch) : 93600, Generator 손실함수(g_loss): 2.674731, Discriminator 손실함수 (d_loss): 0.488028
# 반복(Epoch) : 93700, Generator 손실함수(g_loss): 2.438089, Discriminator 손실함수 (d_loss): 0.509151
# 반복(Epoch) : 93800, Generator 손실함수(g_loss): 2.606866, Discriminator 손실함수 (d_loss): 0.473736
# 반복(Epoch) : 93900, Generator 손실함수(g_loss): 2.616026, Discriminator 손실함수 (d_loss): 0.551421
# 반복(Epoch) : 94000, Generator 손실함수(g_loss): 3.370179, Discriminator 손실함수 (d_loss): 0.363546
# 반복(Epoch) : 94100, Generator 손실함수(g_loss): 2.389393, Discriminator 손실함수 (d_loss): 0.892479
# 반복(Epoch) : 94200, Generator 손실함수(g_loss): 2.366596, Discriminator 손실함수 (d_loss): 0.601477
# 반복(Epoch) : 94300, Generator 손실함수(g_loss): 2.831440, Discriminator 손실함수 (d_loss): 0.814787
# 반복(Epoch) : 94400, Generator 손실함수(g_loss): 2.773102, Discriminator 손실함수 (d_loss): 0.419356
# 반복(Epoch) : 94500, Generator 손실함수(g_loss): 2.370596, Discriminator 손실함수 (d_loss): 0.544717
# 반복(Epoch) : 94600, Generator 손실함수(g_loss): 2.333409, Discriminator 손실함수 (d_loss): 0.587753
# 반복(Epoch) : 94700, Generator 손실함수(g_loss): 2.786588, Discriminator 손실함수 (d_loss): 0.547245
# 반복(Epoch) : 94800, Generator 손실함수(g_loss): 2.333112, Discriminator 손실함수 (d_loss): 0.675788
# 반복(Epoch) : 94900, Generator 손실함수(g_loss): 2.238235, Discriminator 손실함수 (d_loss): 0.422258
# 반복(Epoch) : 95000, Generator 손실함수(g_loss): 2.603846, Discriminator 손실함수 (d_loss): 0.536497
# 반복(Epoch) : 95100, Generator 손실함수(g_loss): 2.627819, Discriminator 손실함수 (d_loss): 0.459669
# 반복(Epoch) : 95200, Generator 손실함수(g_loss): 2.921900, Discriminator 손실함수 (d_loss): 0.414576
# 반복(Epoch) : 95300, Generator 손실함수(g_loss): 2.632721, Discriminator 손실함수 (d_loss): 0.461863
# 반복(Epoch) : 95400, Generator 손실함수(g_loss): 2.420512, Discriminator 손실함수 (d_loss): 0.534711
# 반복(Epoch) : 95500, Generator 손실함수(g_loss): 2.225556, Discriminator 손실함수 (d_loss): 0.524288
# 반복(Epoch) : 95600, Generator 손실함수(g_loss): 2.282875, Discriminator 손실함수 (d_loss): 0.633091
# 반복(Epoch) : 95700, Generator 손실함수(g_loss): 2.387129, Discriminator 손실함수 (d_loss): 0.506474
# 반복(Epoch) : 95800, Generator 손실함수(g_loss): 2.459036, Discriminator 손실함수 (d_loss): 0.468295
# 반복(Epoch) : 95900, Generator 손실함수(g_loss): 2.319998, Discriminator 손실함수 (d_loss): 0.512450
# 반복(Epoch) : 96000, Generator 손실함수(g_loss): 2.858262, Discriminator 손실함수 (d_loss): 0.732581
# 반복(Epoch) : 96100, Generator 손실함수(g_loss): 2.429889, Discriminator 손실함수 (d_loss): 0.515029
# 반복(Epoch) : 96200, Generator 손실함수(g_loss): 2.119591, Discriminator 손실함수 (d_loss): 0.669529
# 반복(Epoch) : 96300, Generator 손실함수(g_loss): 2.699564, Discriminator 손실함수 (d_loss): 0.542416
# 반복(Epoch) : 96400, Generator 손실함수(g_loss): 2.611642, Discriminator 손실함수 (d_loss): 0.625310
# 반복(Epoch) : 96500, Generator 손실함수(g_loss): 2.678946, Discriminator 손실함수 (d_loss): 0.368945
# 반복(Epoch) : 96600, Generator 손실함수(g_loss): 2.647239, Discriminator 손실함수 (d_loss): 0.581635
# 반복(Epoch) : 96700, Generator 손실함수(g_loss): 2.583720, Discriminator 손실함수 (d_loss): 0.561466
# 반복(Epoch) : 96800, Generator 손실함수(g_loss): 2.790367, Discriminator 손실함수 (d_loss): 0.457591
# 반복(Epoch) : 96900, Generator 손실함수(g_loss): 2.471976, Discriminator 손실함수 (d_loss): 0.759207
# 반복(Epoch) : 97000, Generator 손실함수(g_loss): 2.267312, Discriminator 손실함수 (d_loss): 0.564777
# 반복(Epoch) : 97100, Generator 손실함수(g_loss): 2.397310, Discriminator 손실함수 (d_loss): 0.547277
# 반복(Epoch) : 97200, Generator 손실함수(g_loss): 2.703217, Discriminator 손실함수 (d_loss): 0.372616
# 반복(Epoch) : 97300, Generator 손실함수(g_loss): 3.029334, Discriminator 손실함수 (d_loss): 0.500838
# 반복(Epoch) : 97400, Generator 손실함수(g_loss): 2.541012, Discriminator 손실함수 (d_loss): 0.429790
# 반복(Epoch) : 97500, Generator 손실함수(g_loss): 2.518003, Discriminator 손실함수 (d_loss): 0.331576
# 반복(Epoch) : 97600, Generator 손실함수(g_loss): 2.563118, Discriminator 손실함수 (d_loss): 0.518610
# 반복(Epoch) : 97700, Generator 손실함수(g_loss): 2.707403, Discriminator 손실함수 (d_loss): 0.702573
# 반복(Epoch) : 97800, Generator 손실함수(g_loss): 2.701647, Discriminator 손실함수 (d_loss): 0.452846
# 반복(Epoch) : 97900, Generator 손실함수(g_loss): 2.319450, Discriminator 손실함수 (d_loss): 0.513007
# 반복(Epoch) : 98000, Generator 손실함수(g_loss): 2.282568, Discriminator 손실함수 (d_loss): 0.645581
# 반복(Epoch) : 98100, Generator 손실함수(g_loss): 2.710247, Discriminator 손실함수 (d_loss): 0.446442
# 반복(Epoch) : 98200, Generator 손실함수(g_loss): 2.495329, Discriminator 손실함수 (d_loss): 0.439233
# 반복(Epoch) : 98300, Generator 손실함수(g_loss): 2.558708, Discriminator 손실함수 (d_loss): 0.527961
# 반복(Epoch) : 98400, Generator 손실함수(g_loss): 2.542311, Discriminator 손실함수 (d_loss): 0.800213
# 반복(Epoch) : 98500, Generator 손실함수(g_loss): 2.731234, Discriminator 손실함수 (d_loss): 0.745078
# 반복(Epoch) : 98600, Generator 손실함수(g_loss): 2.410080, Discriminator 손실함수 (d_loss): 0.465480
# 반복(Epoch) : 98700, Generator 손실함수(g_loss): 2.556684, Discriminator 손실함수 (d_loss): 0.505195
# 반복(Epoch) : 98800, Generator 손실함수(g_loss): 2.685499, Discriminator 손실함수 (d_loss): 0.361290
# 반복(Epoch) : 98900, Generator 손실함수(g_loss): 2.515251, Discriminator 손실함수 (d_loss): 0.639970
# 반복(Epoch) : 99000, Generator 손실함수(g_loss): 2.818987, Discriminator 손실함수 (d_loss): 0.393650
# 반복(Epoch) : 99100, Generator 손실함수(g_loss): 2.872170, Discriminator 손실함수 (d_loss): 0.533057
# 반복(Epoch) : 99200, Generator 손실함수(g_loss): 2.938266, Discriminator 손실함수 (d_loss): 0.462393
# 반복(Epoch) : 99300, Generator 손실함수(g_loss): 2.735574, Discriminator 손실함수 (d_loss): 0.474549
# 반복(Epoch) : 99400, Generator 손실함수(g_loss): 2.478286, Discriminator 손실함수 (d_loss): 0.586693
# 반복(Epoch) : 99500, Generator 손실함수(g_loss): 2.419463, Discriminator 손실함수 (d_loss): 0.550535
# 반복(Epoch) : 99600, Generator 손실함수(g_loss): 2.407596, Discriminator 손실함수 (d_loss): 0.460314
# 반복(Epoch) : 99700, Generator 손실함수(g_loss): 2.901776, Discriminator 손실함수 (d_loss): 0.559259
# 반복(Epoch) : 99800, Generator 손실함수(g_loss): 2.419880, Discriminator 손실함수 (d_loss): 0.383922
# 반복(Epoch) : 99900, Generator 손실함수(g_loss): 2.353722, Discriminator 손실함수 (d_loss): 0.592711
